# %%
import numpy as np                          # Basic Array and Numaric Operation
import os                                   # use to access the files 
import tarfile                              # use to extract dataset from zip files
import sys
import zipfile                              # to extract zip file


import torch                                # Provides basic tensor operation and nn operation
import torchvision                          # Provides facilities to access image dataset


import my_utils.loadDataset as dl           # create dataloader for selected dataset
import my_utils.loadModel as lm             # facilitate loading and manipulating models
import my_utils.trainModel as tm            # Facilitate training of the model
import my_utils.initialize_pruning as ip    # Initialize and provide basic parmeter require for pruning
import my_utils.facilitate_pruning as fp    # Compute Pruning Value and many things

# %%
def freeze(model,model_name):
    count = 0
    if model_name == 'vgg16':
        for param in model.parameters():
            if count == 30:
              param.requires_grad=True
            else:
              param.requires_grad=False
        count = count+1

# %% [markdown]
# ### Prepare dataloader and set image properties. Check for cuda device and load model

# %%
# set the locationn of the dataset and trai and test data folder name
dl.setFolderLocation(datasets       ='/home/pragnesh/Dataset/',
                     selectedDataset='IntelIC/',
                     train          ='train',
                     test           ='test')
# set the imge properties
dl.setImageSize(224)
dl.setBatchSize = 2
dataLoader = dl.dataLoader()

#load the saved model if have any
load_path = "/home/pragnesh/Model/VGG_IntelIC_v2"
device1 = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
newModel = torch.load(load_path, map_location=torch.device('cpu'))

#if dont have any saved trained model download pretrained model for tranfer learning
# newmodel = lm.load_model(model_name='vgg16',number_of_class=6,pretrainval=False,
#                         freeze_feature=False,device_l=device1)

#print(newModel)

# %% [markdown]
# ### Here we have 3 set of parameter.One for data loader, second for model and third are hyperparameter
# ### Train the model

# %%
logFile = '/home/pragnesh/Dataset/Intel_Image_Classifacation_v2/Logs/ConvModelv2.log'
#tm.device = torch.device('cpu')
tm.fit_one_cycle(#set locations of the dataset, train and test data
                 dataloaders=dataLoader,trainDir=dl.trainDir,testDir=dl.testDir,
                 # Selecat a variant of VGGNet
                 ModelName='vgg16',model=newModel,device_l=device1,
                 # Set all the Hyper-Parameter for training
                 epochs=1, max_lr=0.01, weight_decay=0, L1=0, grad_clip=.1, logFile=logFile)

#Save the  trained model 
SavePath = '/home/pragnesh/Model/vgg16-v2'
torch.save(newModel, SavePath)

# %% [markdown]
# ### Pruning Initialization

# %%
blockList   = ip.createBlockList(newModel)              #ip.getBlockList('vgg16')
featureList = ip.createFeatureList(newModel)
convIdx     = ip.findConvIndex(newModel)
module      = ip.getPruneModule(newModel)
prune_count = ip.getPruneCount(module=module,blocks=blockList,maxpr=.1)
print(f"Block List   = {blockList}\n"
      f"Feature List = {featureList}\n" 
      f"Conv Index   = {convIdx}\n"
      f"Prune Count  = {prune_count}"
      
     )
for i in range(len(module)):
    print(f"{i+1} :{module[i]}")
# Out:
# Block List   = [2, 2, 3, 3, 3]
# Feature List = [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M']
# Conv Index   = [0, 2, 5, 7, 10, 12, 14, 17, 19, 21, 24, 26, 28]
# Prune Count  = [1, 1, 3, 3, 9, 9, 9, 26, 26, 26, 51, 51, 51]
# 1 :Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 2 :Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 3 :Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 4 :Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 5 :Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 6 :Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 7 :Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 8 :Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 9 :Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 10 :Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 11 :Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 12 :Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# 13 :Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))

# %% [markdown]
# ### Pruning Process Starts From Here
# ##### compute score for pruning criteria for candidate convolution pruning layer

# %%
candidateConvLayer = []
st =0
en = 2
for i in range(st,en):
    candidateConvLayer.append(fp.compute_distance_score(module[i]._parameters['weight'],threshold=1))
print("\n\n\nHere is the :",len(candidateConvLayer))
# Out:
# Shape of the tensor: torch.Size([64, 3, 3, 3])
# Print the Dims we want to keep: [0, 1]
# norm shape = torch.Size([64, 3])
# Number Of Features Map in current  layer l     = 64
# Number Of Features Map in previous layer (l-1) = 3
# ...
# Shape of the tensor: torch.Size([64, 64, 3, 3])
# Print the Dims we want to keep: [0, 1]
# norm shape = torch.Size([64, 64])
# Number Of Features Map in current  layer l     = 64
# Number Of Features Map in previous layer (l-1) = 64
# ................................................................
#
#
# Here is the : 2

# %% [markdown]
# #### *Sort the list of score in the ascending order*

# %%
for i in range(len(candidateConvLayer)):
    fp.sort_kernel_by_distance(candidateConvLayer[i])

# %%
print(f'c={len(candidateConvLayer)}, c[] ={len(candidateConvLayer[0])},' 
      f'c[][] = {len(candidateConvLayer[0][0])},c[][][] = {len(candidateConvLayer[0][0][0])}')
# Out:
# c=2, c[] =3,c[][] = 190,c[][][] = 4

# %% [markdown]
# #### *Extract K Elements of ascending List of Score and they will be the minimum score*

# %%
prune_count = ip.getPruneCount(module=module,blocks=blockList,maxpr=0.1,)
newList = []
for i in range(len(candidateConvLayer)):
    newList.append(fp.get_k_element(channel_list=candidateConvLayer[i],k=prune_count[st+i])  )
print(f'c={len(newList)}, c[] ={len(newList[0])},' 
      f'c[][] = {len(newList[0][0])},c[][][] = {len(newList[0][0][0])}')
# Out:
# c=2, c[] =3,c[][] = 1,c[][][] = 4

# %% [markdown]
# ### Now Execute the pruning

# %% [markdown]
# #### Define class to execute custom pruning

# %%
import torch.nn.utils.prune as prune
class KernalPruningMethod(prune.BasePruningMethod):
    PRUNING_TYPE = 'unstructured'
    def compute_mask(self, t, default_mask):
        mask = default_mask.clone()
        #mask.view(-1)[::2] = 0
        size = t.shape
        print(size)
        for k1 in range(len(newList[layer_number-st])):
            for k2 in range(len(newList[layer_number-st][k1])):
                i= newList[layer_number-st][k1][k2][1]
                j= newList[layer_number-st][k1][k2][0]
                
                #print(f"i= {i} , j= {j}")
                
                mask[i][j] = 0
        return mask
def kernal_unstructured(module, name):
    KernalPruningMethod.apply(module, name)
    return module

# %% [markdown]
# ### *Pass the cadidate layer of Conv Net for custom pruning*

# %%
layer_number = 0
for i in range(st,en):
    layer_number = i
    kernal_unstructured(module[i], name = 'weight')
    layer_number += 1
# Out:
# torch.Size([64, 3, 3, 3])
# torch.Size([64, 64, 3, 3])

# %% [markdown]
# ##### commit the pruning parameter

# %%
for i in range(st,en):
    prune.remove(module[i], 'weight')

# %% [markdown]
# ### Deep Copy Code

# %%
def updateFeatureList(featureList,prune_count,start,end):
    j=0
    i=st
    while j < en:
        if featureList[i] == 'M':
            i+=1
            continue
        else:
            featureList[i] = featureList[i] - prune_count[j]
            j+=1
            i+=1
    return featureList
featureList= updateFeatureList(featureList=featureList, prune_count=prune_count,start=st,end=en)

# %%
print(featureList)
# Out:
# [63, 63, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M']

# %%
#featureList = ip.createFeatureList(newModel)

# %%
tempModel = lm.create_vgg_from_feature_list(featureList)
print(tempModel)
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 63, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(63, 63, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(63, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=10, bias=True)
#   )
# )

# %%
lm.freeze(model=tempModel,model_name='vgg16')

# %%
def deepCopy(destModel,sourceModel,featureList):
    count=0
    for i in range(len(sourceModel.features)):
        if str(sourceModel.features[i]).find('Conv') != -1:
            size = sourceModel.features[i]._parameters['weight'].shape
            for fin in range(size[1]):
                j=0
                for fout in range(size[0]):
                    if torch.norm(sourceModel.features[i]._parameters['weight'][fout][fin]) != 0:
                        print(f'i ={i} , j={j}, fin = {fin}, fout= {fout}')
                        if j>=featureList[count]:
                            break
                        destModel.features[i]._parameters['weight'][j][fin]=sourceModel.features[i]._parameters['weight'][fout][fin]
                        j = j+1
            count = count +1
deepCopy(destModel=tempModel,sourceModel=newModel,featureList=featureList)
# Out:
# i =0 , j=0, fin = 0, fout= 0
# i =0 , j=1, fin = 0, fout= 1
# i =0 , j=2, fin = 0, fout= 2
# i =0 , j=3, fin = 0, fout= 3
# i =0 , j=4, fin = 0, fout= 4
# i =0 , j=5, fin = 0, fout= 5
# i =0 , j=6, fin = 0, fout= 6
# i =0 , j=7, fin = 0, fout= 7
# i =0 , j=8, fin = 0, fout= 8
# i =0 , j=9, fin = 0, fout= 9
# i =0 , j=10, fin = 0, fout= 10
# i =0 , j=11, fin = 0, fout= 11
# i =0 , j=12, fin = 0, fout= 12
# i =0 , j=13, fin = 0, fout= 13
# i =0 , j=14, fin = 0, fout= 14
# i =0 , j=15, fin = 0, fout= 15
# i =0 , j=16, fin = 0, fout= 16
# i =0 , j=17, fin = 0, fout= 17
# i =0 , j=18, fin = 0, fout= 18
# i =0 , j=19, fin = 0, fout= 20
# i =0 , j=20, fin = 0, fout= 21
# i =0 , j=21, fin = 0, fout= 22
# i =0 , j=22, fin = 0, fout= 23
# i =0 , j=23, fin = 0, fout= 24
# i =0 , j=24, fin = 0, fout= 25
# i =0 , j=25, fin = 0, fout= 26
# i =0 , j=26, fin = 0, fout= 27
# i =0 , j=27, fin = 0, fout= 28
# i =0 , j=28, fin = 0, fout= 29
# i =0 , j=29, fin = 0, fout= 30
# i =0 , j=30, fin = 0, fout= 31
# i =0 , j=31, fin = 0, fout= 32
# i =0 , j=32, fin = 0, fout= 33
# i =0 , j=33, fin = 0, fout= 34
# i =0 , j=34, fin = 0, fout= 35
# i =0 , j=35, fin = 0, fout= 36
# i =0 , j=36, fin = 0, fout= 37
# i =0 , j=37, fin = 0, fout= 38
# i =0 , j=38, fin = 0, fout= 39
# i =0 , j=39, fin = 0, fout= 40
# i =0 , j=40, fin = 0, fout= 41
# i =0 , j=41, fin = 0, fout= 42
# i =0 , j=42, fin = 0, fout= 43
# i =0 , j=43, fin = 0, fout= 44
# i =0 , j=44, fin = 0, fout= 45
# i =0 , j=45, fin = 0, fout= 46
# i =0 , j=46, fin = 0, fout= 47
# i =0 , j=47, fin = 0, fout= 48
# i =0 , j=48, fin = 0, fout= 49
# i =0 , j=49, fin = 0, fout= 50
# i =0 , j=50, fin = 0, fout= 51
# i =0 , j=51, fin = 0, fout= 52
# i =0 , j=52, fin = 0, fout= 53
# i =0 , j=53, fin = 0, fout= 54
# i =0 , j=54, fin = 0, fout= 55
# i =0 , j=55, fin = 0, fout= 56
# i =0 , j=56, fin = 0, fout= 57
# i =0 , j=57, fin = 0, fout= 58
# i =0 , j=58, fin = 0, fout= 59
# i =0 , j=59, fin = 0, fout= 60
# i =0 , j=60, fin = 0, fout= 61
# i =0 , j=61, fin = 0, fout= 62
# i =0 , j=62, fin = 0, fout= 63
# i =0 , j=0, fin = 1, fout= 0
# i =0 , j=1, fin = 1, fout= 1
# i =0 , j=2, fin = 1, fout= 2
# i =0 , j=3, fin = 1, fout= 3
# i =0 , j=4, fin = 1, fout= 4
# i =0 , j=5, fin = 1, fout= 5
# i =0 , j=6, fin = 1, fout= 6
# i =0 , j=7, fin = 1, fout= 7
# i =0 , j=8, fin = 1, fout= 8
# i =0 , j=9, fin = 1, fout= 9
# i =0 , j=10, fin = 1, fout= 10
# i =0 , j=11, fin = 1, fout= 11
# i =0 , j=12, fin = 1, fout= 12
# i =0 , j=13, fin = 1, fout= 14
# i =0 , j=14, fin = 1, fout= 15
# i =0 , j=15, fin = 1, fout= 16
# i =0 , j=16, fin = 1, fout= 17
# i =0 , j=17, fin = 1, fout= 18
# i =0 , j=18, fin = 1, fout= 19
# i =0 , j=19, fin = 1, fout= 20
# i =0 , j=20, fin = 1, fout= 21
# i =0 , j=21, fin = 1, fout= 22
# i =0 , j=22, fin = 1, fout= 23
# i =0 , j=23, fin = 1, fout= 24
# i =0 , j=24, fin = 1, fout= 25
# i =0 , j=25, fin = 1, fout= 26
# i =0 , j=26, fin = 1, fout= 27
# i =0 , j=27, fin = 1, fout= 28
# i =0 , j=28, fin = 1, fout= 29
# i =0 , j=29, fin = 1, fout= 30
# i =0 , j=30, fin = 1, fout= 31
# i =0 , j=31, fin = 1, fout= 32
# i =0 , j=32, fin = 1, fout= 33
# i =0 , j=33, fin = 1, fout= 34
# i =0 , j=34, fin = 1, fout= 35
# i =0 , j=35, fin = 1, fout= 36
# i =0 , j=36, fin = 1, fout= 37
# i =0 , j=37, fin = 1, fout= 38
# i =0 , j=38, fin = 1, fout= 39
# i =0 , j=39, fin = 1, fout= 40
# i =0 , j=40, fin = 1, fout= 41
# i =0 , j=41, fin = 1, fout= 42
# i =0 , j=42, fin = 1, fout= 43
# i =0 , j=43, fin = 1, fout= 44
# i =0 , j=44, fin = 1, fout= 45
# i =0 , j=45, fin = 1, fout= 46
# i =0 , j=46, fin = 1, fout= 47
# i =0 , j=47, fin = 1, fout= 48
# i =0 , j=48, fin = 1, fout= 49
# i =0 , j=49, fin = 1, fout= 50
# i =0 , j=50, fin = 1, fout= 51
# i =0 , j=51, fin = 1, fout= 52
# i =0 , j=52, fin = 1, fout= 53
# i =0 , j=53, fin = 1, fout= 54
# i =0 , j=54, fin = 1, fout= 55
# i =0 , j=55, fin = 1, fout= 56
# i =0 , j=56, fin = 1, fout= 57
# i =0 , j=57, fin = 1, fout= 58
# i =0 , j=58, fin = 1, fout= 59
# i =0 , j=59, fin = 1, fout= 60
# i =0 , j=60, fin = 1, fout= 61
# i =0 , j=61, fin = 1, fout= 62
# i =0 , j=62, fin = 1, fout= 63
# i =0 , j=0, fin = 2, fout= 0
# i =0 , j=1, fin = 2, fout= 1
# i =0 , j=2, fin = 2, fout= 2
# i =0 , j=3, fin = 2, fout= 3
# i =0 , j=4, fin = 2, fout= 4
# i =0 , j=5, fin = 2, fout= 5
# i =0 , j=6, fin = 2, fout= 6
# i =0 , j=7, fin = 2, fout= 7
# i =0 , j=8, fin = 2, fout= 8
# i =0 , j=9, fin = 2, fout= 9
# i =0 , j=10, fin = 2, fout= 10
# i =0 , j=11, fin = 2, fout= 11
# i =0 , j=12, fin = 2, fout= 12
# i =0 , j=13, fin = 2, fout= 13
# i =0 , j=14, fin = 2, fout= 14
# i =0 , j=15, fin = 2, fout= 15
# i =0 , j=16, fin = 2, fout= 16
# i =0 , j=17, fin = 2, fout= 17
# i =0 , j=18, fin = 2, fout= 18
# i =0 , j=19, fin = 2, fout= 19
# i =0 , j=20, fin = 2, fout= 20
# i =0 , j=21, fin = 2, fout= 21
# i =0 , j=22, fin = 2, fout= 22
# i =0 , j=23, fin = 2, fout= 23
# i =0 , j=24, fin = 2, fout= 24
# i =0 , j=25, fin = 2, fout= 25
# i =0 , j=26, fin = 2, fout= 26
# i =0 , j=27, fin = 2, fout= 27
# i =0 , j=28, fin = 2, fout= 28
# i =0 , j=29, fin = 2, fout= 29
# i =0 , j=30, fin = 2, fout= 30
# i =0 , j=31, fin = 2, fout= 31
# i =0 , j=32, fin = 2, fout= 32
# i =0 , j=33, fin = 2, fout= 33
# i =0 , j=34, fin = 2, fout= 34
# i =0 , j=35, fin = 2, fout= 35
# i =0 , j=36, fin = 2, fout= 36
# i =0 , j=37, fin = 2, fout= 37
# i =0 , j=38, fin = 2, fout= 38
# i =0 , j=39, fin = 2, fout= 39
# i =0 , j=40, fin = 2, fout= 40
# i =0 , j=41, fin = 2, fout= 41
# i =0 , j=42, fin = 2, fout= 42
# i =0 , j=43, fin = 2, fout= 43
# i =0 , j=44, fin = 2, fout= 44
# i =0 , j=45, fin = 2, fout= 45
# i =0 , j=46, fin = 2, fout= 46
# i =0 , j=47, fin = 2, fout= 47
# i =0 , j=48, fin = 2, fout= 48
# i =0 , j=49, fin = 2, fout= 49
# i =0 , j=50, fin = 2, fout= 51
# i =0 , j=51, fin = 2, fout= 52
# i =0 , j=52, fin = 2, fout= 53
# i =0 , j=53, fin = 2, fout= 54
# i =0 , j=54, fin = 2, fout= 55
# i =0 , j=55, fin = 2, fout= 56
# i =0 , j=56, fin = 2, fout= 57
# i =0 , j=57, fin = 2, fout= 58
# i =0 , j=58, fin = 2, fout= 59
# i =0 , j=59, fin = 2, fout= 60
# i =0 , j=60, fin = 2, fout= 61
# i =0 , j=61, fin = 2, fout= 62
# i =0 , j=62, fin = 2, fout= 63
# i =2 , j=0, fin = 0, fout= 0
# i =2 , j=1, fin = 0, fout= 1
# i =2 , j=2, fin = 0, fout= 2
# i =2 , j=3, fin = 0, fout= 3
# i =2 , j=4, fin = 0, fout= 4
# i =2 , j=5, fin = 0, fout= 5
# i =2 , j=6, fin = 0, fout= 6
# i =2 , j=7, fin = 0, fout= 7
# i =2 , j=8, fin = 0, fout= 8
# i =2 , j=9, fin = 0, fout= 9
# i =2 , j=10, fin = 0, fout= 10
# i =2 , j=11, fin = 0, fout= 11
# i =2 , j=12, fin = 0, fout= 12
# i =2 , j=13, fin = 0, fout= 13
# i =2 , j=14, fin = 0, fout= 14
# i =2 , j=15, fin = 0, fout= 15
# i =2 , j=16, fin = 0, fout= 17
# i =2 , j=17, fin = 0, fout= 18
# i =2 , j=18, fin = 0, fout= 19
# i =2 , j=19, fin = 0, fout= 20
# i =2 , j=20, fin = 0, fout= 21
# i =2 , j=21, fin = 0, fout= 22
# i =2 , j=22, fin = 0, fout= 23
# i =2 , j=23, fin = 0, fout= 24
# i =2 , j=24, fin = 0, fout= 25
# i =2 , j=25, fin = 0, fout= 26
# i =2 , j=26, fin = 0, fout= 27
# i =2 , j=27, fin = 0, fout= 28
# i =2 , j=28, fin = 0, fout= 29
# i =2 , j=29, fin = 0, fout= 30
# i =2 , j=30, fin = 0, fout= 31
# i =2 , j=31, fin = 0, fout= 32
# i =2 , j=32, fin = 0, fout= 33
# i =2 , j=33, fin = 0, fout= 34
# i =2 , j=34, fin = 0, fout= 35
# i =2 , j=35, fin = 0, fout= 36
# i =2 , j=36, fin = 0, fout= 37
# i =2 , j=37, fin = 0, fout= 38
# i =2 , j=38, fin = 0, fout= 39
# i =2 , j=39, fin = 0, fout= 40
# i =2 , j=40, fin = 0, fout= 41
# i =2 , j=41, fin = 0, fout= 42
# i =2 , j=42, fin = 0, fout= 43
# i =2 , j=43, fin = 0, fout= 44
# i =2 , j=44, fin = 0, fout= 45
# i =2 , j=45, fin = 0, fout= 46
# i =2 , j=46, fin = 0, fout= 47
# i =2 , j=47, fin = 0, fout= 48
# i =2 , j=48, fin = 0, fout= 49
# i =2 , j=49, fin = 0, fout= 50
# i =2 , j=50, fin = 0, fout= 51
# i =2 , j=51, fin = 0, fout= 52
# i =2 , j=52, fin = 0, fout= 53
# i =2 , j=53, fin = 0, fout= 54
# i =2 , j=54, fin = 0, fout= 55
# i =2 , j=55, fin = 0, fout= 56
# i =2 , j=56, fin = 0, fout= 57
# i =2 , j=57, fin = 0, fout= 58
# i =2 , j=58, fin = 0, fout= 59
# i =2 , j=59, fin = 0, fout= 60
# i =2 , j=60, fin = 0, fout= 61
# i =2 , j=61, fin = 0, fout= 62
# i =2 , j=62, fin = 0, fout= 63
# i =2 , j=0, fin = 1, fout= 0
# i =2 , j=1, fin = 1, fout= 1
# i =2 , j=2, fin = 1, fout= 2
# i =2 , j=3, fin = 1, fout= 3
# i =2 , j=4, fin = 1, fout= 4
# i =2 , j=5, fin = 1, fout= 5
# i =2 , j=6, fin = 1, fout= 6
# i =2 , j=7, fin = 1, fout= 7
# i =2 , j=8, fin = 1, fout= 8
# i =2 , j=9, fin = 1, fout= 9
# i =2 , j=10, fin = 1, fout= 10
# i =2 , j=11, fin = 1, fout= 11
# i =2 , j=12, fin = 1, fout= 12
# i =2 , j=13, fin = 1, fout= 13
# i =2 , j=14, fin = 1, fout= 14
# i =2 , j=15, fin = 1, fout= 15
# i =2 , j=16, fin = 1, fout= 16
# i =2 , j=17, fin = 1, fout= 17
# i =2 , j=18, fin = 1, fout= 18
# i =2 , j=19, fin = 1, fout= 19
# i =2 , j=20, fin = 1, fout= 20
# i =2 , j=21, fin = 1, fout= 21
# i =2 , j=22, fin = 1, fout= 22
# i =2 , j=23, fin = 1, fout= 23
# i =2 , j=24, fin = 1, fout= 24
# i =2 , j=25, fin = 1, fout= 25
# i =2 , j=26, fin = 1, fout= 26
# i =2 , j=27, fin = 1, fout= 27
# i =2 , j=28, fin = 1, fout= 28
# i =2 , j=29, fin = 1, fout= 29
# i =2 , j=30, fin = 1, fout= 30
# i =2 , j=31, fin = 1, fout= 31
# i =2 , j=32, fin = 1, fout= 32
# i =2 , j=33, fin = 1, fout= 33
# i =2 , j=34, fin = 1, fout= 34
# i =2 , j=35, fin = 1, fout= 35
# i =2 , j=36, fin = 1, fout= 36
# i =2 , j=37, fin = 1, fout= 37
# i =2 , j=38, fin = 1, fout= 38
# i =2 , j=39, fin = 1, fout= 39
# i =2 , j=40, fin = 1, fout= 40
# i =2 , j=41, fin = 1, fout= 41
# i =2 , j=42, fin = 1, fout= 42
# i =2 , j=43, fin = 1, fout= 43
# i =2 , j=44, fin = 1, fout= 44
# i =2 , j=45, fin = 1, fout= 46
# i =2 , j=46, fin = 1, fout= 47
# i =2 , j=47, fin = 1, fout= 48
# i =2 , j=48, fin = 1, fout= 49
# i =2 , j=49, fin = 1, fout= 50
# i =2 , j=50, fin = 1, fout= 51
# i =2 , j=51, fin = 1, fout= 52
# i =2 , j=52, fin = 1, fout= 53
# i =2 , j=53, fin = 1, fout= 54
# i =2 , j=54, fin = 1, fout= 55
# i =2 , j=55, fin = 1, fout= 56
# i =2 , j=56, fin = 1, fout= 57
# i =2 , j=57, fin = 1, fout= 58
# i =2 , j=58, fin = 1, fout= 59
# i =2 , j=59, fin = 1, fout= 60
# i =2 , j=60, fin = 1, fout= 61
# i =2 , j=61, fin = 1, fout= 62
# i =2 , j=62, fin = 1, fout= 63
# i =2 , j=0, fin = 2, fout= 0
# i =2 , j=1, fin = 2, fout= 1
# i =2 , j=2, fin = 2, fout= 2
# i =2 , j=3, fin = 2, fout= 3
# i =2 , j=4, fin = 2, fout= 4
# i =2 , j=5, fin = 2, fout= 5
# i =2 , j=6, fin = 2, fout= 6
# i =2 , j=7, fin = 2, fout= 7
# i =2 , j=8, fin = 2, fout= 8
# i =2 , j=9, fin = 2, fout= 9
# i =2 , j=10, fin = 2, fout= 11
# i =2 , j=11, fin = 2, fout= 12
# i =2 , j=12, fin = 2, fout= 13
# i =2 , j=13, fin = 2, fout= 14
# i =2 , j=14, fin = 2, fout= 15
# i =2 , j=15, fin = 2, fout= 16
# i =2 , j=16, fin = 2, fout= 17
# i =2 , j=17, fin = 2, fout= 18
# i =2 , j=18, fin = 2, fout= 19
# i =2 , j=19, fin = 2, fout= 20
# i =2 , j=20, fin = 2, fout= 21
# i =2 , j=21, fin = 2, fout= 22
# i =2 , j=22, fin = 2, fout= 23
# i =2 , j=23, fin = 2, fout= 24
# i =2 , j=24, fin = 2, fout= 25
# i =2 , j=25, fin = 2, fout= 26
# i =2 , j=26, fin = 2, fout= 27
# i =2 , j=27, fin = 2, fout= 28
# i =2 , j=28, fin = 2, fout= 29
# i =2 , j=29, fin = 2, fout= 30
# i =2 , j=30, fin = 2, fout= 31
# i =2 , j=31, fin = 2, fout= 32
# i =2 , j=32, fin = 2, fout= 33
# i =2 , j=33, fin = 2, fout= 34
# i =2 , j=34, fin = 2, fout= 35
# i =2 , j=35, fin = 2, fout= 36
# i =2 , j=36, fin = 2, fout= 37
# i =2 , j=37, fin = 2, fout= 38
# i =2 , j=38, fin = 2, fout= 39
# i =2 , j=39, fin = 2, fout= 40
# i =2 , j=40, fin = 2, fout= 41
# i =2 , j=41, fin = 2, fout= 42
# i =2 , j=42, fin = 2, fout= 43
# i =2 , j=43, fin = 2, fout= 44
# i =2 , j=44, fin = 2, fout= 45
# i =2 , j=45, fin = 2, fout= 46
# i =2 , j=46, fin = 2, fout= 47
# i =2 , j=47, fin = 2, fout= 48
# i =2 , j=48, fin = 2, fout= 49
# i =2 , j=49, fin = 2, fout= 50
# i =2 , j=50, fin = 2, fout= 51
# i =2 , j=51, fin = 2, fout= 52
# i =2 , j=52, fin = 2, fout= 53
# i =2 , j=53, fin = 2, fout= 54
# i =2 , j=54, fin = 2, fout= 55
# i =2 , j=55, fin = 2, fout= 56
# i =2 , j=56, fin = 2, fout= 57
# i =2 , j=57, fin = 2, fout= 58
# i =2 , j=58, fin = 2, fout= 59
# i =2 , j=59, fin = 2, fout= 60
# i =2 , j=60, fin = 2, fout= 61
# i =2 , j=61, fin = 2, fout= 62
# i =2 , j=62, fin = 2, fout= 63
# i =2 , j=0, fin = 3, fout= 0
# i =2 , j=1, fin = 3, fout= 1
# i =2 , j=2, fin = 3, fout= 2
# i =2 , j=3, fin = 3, fout= 3
# i =2 , j=4, fin = 3, fout= 4
# i =2 , j=5, fin = 3, fout= 5
# i =2 , j=6, fin = 3, fout= 6
# i =2 , j=7, fin = 3, fout= 7
# i =2 , j=8, fin = 3, fout= 8
# i =2 , j=9, fin = 3, fout= 9
# i =2 , j=10, fin = 3, fout= 10
# i =2 , j=11, fin = 3, fout= 11
# i =2 , j=12, fin = 3, fout= 12
# i =2 , j=13, fin = 3, fout= 13
# i =2 , j=14, fin = 3, fout= 14
# i =2 , j=15, fin = 3, fout= 15
# i =2 , j=16, fin = 3, fout= 16
# i =2 , j=17, fin = 3, fout= 17
# i =2 , j=18, fin = 3, fout= 18
# i =2 , j=19, fin = 3, fout= 19
# i =2 , j=20, fin = 3, fout= 20
# i =2 , j=21, fin = 3, fout= 21
# i =2 , j=22, fin = 3, fout= 22
# i =2 , j=23, fin = 3, fout= 23
# i =2 , j=24, fin = 3, fout= 24
# i =2 , j=25, fin = 3, fout= 25
# i =2 , j=26, fin = 3, fout= 26
# i =2 , j=27, fin = 3, fout= 27
# i =2 , j=28, fin = 3, fout= 28
# i =2 , j=29, fin = 3, fout= 29
# i =2 , j=30, fin = 3, fout= 30
# i =2 , j=31, fin = 3, fout= 31
# i =2 , j=32, fin = 3, fout= 33
# i =2 , j=33, fin = 3, fout= 34
# i =2 , j=34, fin = 3, fout= 35
# i =2 , j=35, fin = 3, fout= 36
# i =2 , j=36, fin = 3, fout= 37
# i =2 , j=37, fin = 3, fout= 38
# i =2 , j=38, fin = 3, fout= 39
# i =2 , j=39, fin = 3, fout= 40
# i =2 , j=40, fin = 3, fout= 41
# i =2 , j=41, fin = 3, fout= 42
# i =2 , j=42, fin = 3, fout= 43
# i =2 , j=43, fin = 3, fout= 44
# i =2 , j=44, fin = 3, fout= 45
# i =2 , j=45, fin = 3, fout= 46
# i =2 , j=46, fin = 3, fout= 47
# i =2 , j=47, fin = 3, fout= 48
# i =2 , j=48, fin = 3, fout= 49
# i =2 , j=49, fin = 3, fout= 50
# i =2 , j=50, fin = 3, fout= 51
# i =2 , j=51, fin = 3, fout= 52
# i =2 , j=52, fin = 3, fout= 53
# i =2 , j=53, fin = 3, fout= 54
# i =2 , j=54, fin = 3, fout= 55
# i =2 , j=55, fin = 3, fout= 56
# i =2 , j=56, fin = 3, fout= 57
# i =2 , j=57, fin = 3, fout= 58
# i =2 , j=58, fin = 3, fout= 59
# i =2 , j=59, fin = 3, fout= 60
# i =2 , j=60, fin = 3, fout= 61
# i =2 , j=61, fin = 3, fout= 62
# i =2 , j=62, fin = 3, fout= 63
# i =2 , j=0, fin = 4, fout= 0
# i =2 , j=1, fin = 4, fout= 1
# i =2 , j=2, fin = 4, fout= 2
# i =2 , j=3, fin = 4, fout= 3
# i =2 , j=4, fin = 4, fout= 4
# i =2 , j=5, fin = 4, fout= 5
# i =2 , j=6, fin = 4, fout= 6
# i =2 , j=7, fin = 4, fout= 8
# i =2 , j=8, fin = 4, fout= 9
# i =2 , j=9, fin = 4, fout= 10
# i =2 , j=10, fin = 4, fout= 11
# i =2 , j=11, fin = 4, fout= 12
# i =2 , j=12, fin = 4, fout= 13
# i =2 , j=13, fin = 4, fout= 14
# i =2 , j=14, fin = 4, fout= 15
# i =2 , j=15, fin = 4, fout= 16
# i =2 , j=16, fin = 4, fout= 17
# i =2 , j=17, fin = 4, fout= 18
# i =2 , j=18, fin = 4, fout= 19
# i =2 , j=19, fin = 4, fout= 20
# i =2 , j=20, fin = 4, fout= 21
# i =2 , j=21, fin = 4, fout= 22
# i =2 , j=22, fin = 4, fout= 23
# i =2 , j=23, fin = 4, fout= 24
# i =2 , j=24, fin = 4, fout= 25
# i =2 , j=25, fin = 4, fout= 26
# i =2 , j=26, fin = 4, fout= 27
# i =2 , j=27, fin = 4, fout= 28
# i =2 , j=28, fin = 4, fout= 29
# i =2 , j=29, fin = 4, fout= 30
# i =2 , j=30, fin = 4, fout= 31
# i =2 , j=31, fin = 4, fout= 32
# i =2 , j=32, fin = 4, fout= 33
# i =2 , j=33, fin = 4, fout= 34
# i =2 , j=34, fin = 4, fout= 35
# i =2 , j=35, fin = 4, fout= 36
# i =2 , j=36, fin = 4, fout= 37
# i =2 , j=37, fin = 4, fout= 38
# i =2 , j=38, fin = 4, fout= 39
# i =2 , j=39, fin = 4, fout= 40
# i =2 , j=40, fin = 4, fout= 41
# i =2 , j=41, fin = 4, fout= 42
# i =2 , j=42, fin = 4, fout= 43
# i =2 , j=43, fin = 4, fout= 44
# i =2 , j=44, fin = 4, fout= 45
# i =2 , j=45, fin = 4, fout= 46
# i =2 , j=46, fin = 4, fout= 47
# i =2 , j=47, fin = 4, fout= 48
# i =2 , j=48, fin = 4, fout= 49
# i =2 , j=49, fin = 4, fout= 50
# i =2 , j=50, fin = 4, fout= 51
# i =2 , j=51, fin = 4, fout= 52
# i =2 , j=52, fin = 4, fout= 53
# i =2 , j=53, fin = 4, fout= 54
# i =2 , j=54, fin = 4, fout= 55
# i =2 , j=55, fin = 4, fout= 56
# i =2 , j=56, fin = 4, fout= 57
# i =2 , j=57, fin = 4, fout= 58
# i =2 , j=58, fin = 4, fout= 59
# i =2 , j=59, fin = 4, fout= 60
# i =2 , j=60, fin = 4, fout= 61
# i =2 , j=61, fin = 4, fout= 62
# i =2 , j=62, fin = 4, fout= 63
# i =2 , j=0, fin = 5, fout= 0
# i =2 , j=1, fin = 5, fout= 1
# i =2 , j=2, fin = 5, fout= 2
# i =2 , j=3, fin = 5, fout= 3
# i =2 , j=4, fin = 5, fout= 4
# i =2 , j=5, fin = 5, fout= 5
# i =2 , j=6, fin = 5, fout= 6
# i =2 , j=7, fin = 5, fout= 7
# i =2 , j=8, fin = 5, fout= 8
# i =2 , j=9, fin = 5, fout= 9
# i =2 , j=10, fin = 5, fout= 10
# i =2 , j=11, fin = 5, fout= 11
# i =2 , j=12, fin = 5, fout= 12
# i =2 , j=13, fin = 5, fout= 13
# i =2 , j=14, fin = 5, fout= 14
# i =2 , j=15, fin = 5, fout= 15
# i =2 , j=16, fin = 5, fout= 17
# i =2 , j=17, fin = 5, fout= 18
# i =2 , j=18, fin = 5, fout= 19
# i =2 , j=19, fin = 5, fout= 20
# i =2 , j=20, fin = 5, fout= 21
# i =2 , j=21, fin = 5, fout= 22
# i =2 , j=22, fin = 5, fout= 23
# i =2 , j=23, fin = 5, fout= 24
# i =2 , j=24, fin = 5, fout= 25
# i =2 , j=25, fin = 5, fout= 26
# i =2 , j=26, fin = 5, fout= 27
# i =2 , j=27, fin = 5, fout= 28
# i =2 , j=28, fin = 5, fout= 29
# i =2 , j=29, fin = 5, fout= 30
# i =2 , j=30, fin = 5, fout= 31
# i =2 , j=31, fin = 5, fout= 32
# i =2 , j=32, fin = 5, fout= 33
# i =2 , j=33, fin = 5, fout= 34
# i =2 , j=34, fin = 5, fout= 35
# i =2 , j=35, fin = 5, fout= 36
# i =2 , j=36, fin = 5, fout= 37
# i =2 , j=37, fin = 5, fout= 38
# i =2 , j=38, fin = 5, fout= 39
# i =2 , j=39, fin = 5, fout= 40
# i =2 , j=40, fin = 5, fout= 41
# i =2 , j=41, fin = 5, fout= 42
# i =2 , j=42, fin = 5, fout= 43
# i =2 , j=43, fin = 5, fout= 44
# i =2 , j=44, fin = 5, fout= 45
# i =2 , j=45, fin = 5, fout= 46
# i =2 , j=46, fin = 5, fout= 47
# i =2 , j=47, fin = 5, fout= 48
# i =2 , j=48, fin = 5, fout= 49
# i =2 , j=49, fin = 5, fout= 50
# i =2 , j=50, fin = 5, fout= 51
# i =2 , j=51, fin = 5, fout= 52
# i =2 , j=52, fin = 5, fout= 53
# i =2 , j=53, fin = 5, fout= 54
# i =2 , j=54, fin = 5, fout= 55
# i =2 , j=55, fin = 5, fout= 56
# i =2 , j=56, fin = 5, fout= 57
# i =2 , j=57, fin = 5, fout= 58
# i =2 , j=58, fin = 5, fout= 59
# i =2 , j=59, fin = 5, fout= 60
# i =2 , j=60, fin = 5, fout= 61
# i =2 , j=61, fin = 5, fout= 62
# i =2 , j=62, fin = 5, fout= 63
# i =2 , j=0, fin = 6, fout= 0
# i =2 , j=1, fin = 6, fout= 1
# i =2 , j=2, fin = 6, fout= 2
# i =2 , j=3, fin = 6, fout= 3
# i =2 , j=4, fin = 6, fout= 4
# i =2 , j=5, fin = 6, fout= 5
# i =2 , j=6, fin = 6, fout= 6
# i =2 , j=7, fin = 6, fout= 7
# i =2 , j=8, fin = 6, fout= 8
# i =2 , j=9, fin = 6, fout= 9
# i =2 , j=10, fin = 6, fout= 10
# i =2 , j=11, fin = 6, fout= 11
# i =2 , j=12, fin = 6, fout= 12
# i =2 , j=13, fin = 6, fout= 13
# i =2 , j=14, fin = 6, fout= 14
# i =2 , j=15, fin = 6, fout= 15
# i =2 , j=16, fin = 6, fout= 16
# i =2 , j=17, fin = 6, fout= 17
# i =2 , j=18, fin = 6, fout= 18
# i =2 , j=19, fin = 6, fout= 19
# i =2 , j=20, fin = 6, fout= 20
# i =2 , j=21, fin = 6, fout= 21
# i =2 , j=22, fin = 6, fout= 23
# i =2 , j=23, fin = 6, fout= 24
# i =2 , j=24, fin = 6, fout= 25
# i =2 , j=25, fin = 6, fout= 26
# i =2 , j=26, fin = 6, fout= 27
# i =2 , j=27, fin = 6, fout= 28
# i =2 , j=28, fin = 6, fout= 29
# i =2 , j=29, fin = 6, fout= 30
# i =2 , j=30, fin = 6, fout= 31
# i =2 , j=31, fin = 6, fout= 32
# i =2 , j=32, fin = 6, fout= 33
# i =2 , j=33, fin = 6, fout= 34
# i =2 , j=34, fin = 6, fout= 35
# i =2 , j=35, fin = 6, fout= 36
# i =2 , j=36, fin = 6, fout= 37
# i =2 , j=37, fin = 6, fout= 38
# i =2 , j=38, fin = 6, fout= 39
# i =2 , j=39, fin = 6, fout= 40
# i =2 , j=40, fin = 6, fout= 41
# i =2 , j=41, fin = 6, fout= 42
# i =2 , j=42, fin = 6, fout= 43
# i =2 , j=43, fin = 6, fout= 44
# i =2 , j=44, fin = 6, fout= 45
# i =2 , j=45, fin = 6, fout= 46
# i =2 , j=46, fin = 6, fout= 47
# i =2 , j=47, fin = 6, fout= 48
# i =2 , j=48, fin = 6, fout= 49
# i =2 , j=49, fin = 6, fout= 50
# i =2 , j=50, fin = 6, fout= 51
# i =2 , j=51, fin = 6, fout= 52
# i =2 , j=52, fin = 6, fout= 53
# i =2 , j=53, fin = 6, fout= 54
# i =2 , j=54, fin = 6, fout= 55
# i =2 , j=55, fin = 6, fout= 56
# i =2 , j=56, fin = 6, fout= 57
# i =2 , j=57, fin = 6, fout= 58
# i =2 , j=58, fin = 6, fout= 59
# i =2 , j=59, fin = 6, fout= 60
# i =2 , j=60, fin = 6, fout= 61
# i =2 , j=61, fin = 6, fout= 62
# i =2 , j=62, fin = 6, fout= 63
# i =2 , j=0, fin = 7, fout= 0
# i =2 , j=1, fin = 7, fout= 1
# i =2 , j=2, fin = 7, fout= 2
# i =2 , j=3, fin = 7, fout= 3
# i =2 , j=4, fin = 7, fout= 4
# i =2 , j=5, fin = 7, fout= 5
# i =2 , j=6, fin = 7, fout= 6
# i =2 , j=7, fin = 7, fout= 7
# i =2 , j=8, fin = 7, fout= 8
# i =2 , j=9, fin = 7, fout= 9
# i =2 , j=10, fin = 7, fout= 10
# i =2 , j=11, fin = 7, fout= 11
# i =2 , j=12, fin = 7, fout= 12
# i =2 , j=13, fin = 7, fout= 13
# i =2 , j=14, fin = 7, fout= 14
# i =2 , j=15, fin = 7, fout= 15
# i =2 , j=16, fin = 7, fout= 16
# i =2 , j=17, fin = 7, fout= 17
# i =2 , j=18, fin = 7, fout= 18
# i =2 , j=19, fin = 7, fout= 19
# i =2 , j=20, fin = 7, fout= 20
# i =2 , j=21, fin = 7, fout= 21
# i =2 , j=22, fin = 7, fout= 22
# i =2 , j=23, fin = 7, fout= 23
# i =2 , j=24, fin = 7, fout= 24
# i =2 , j=25, fin = 7, fout= 25
# i =2 , j=26, fin = 7, fout= 26
# i =2 , j=27, fin = 7, fout= 27
# i =2 , j=28, fin = 7, fout= 28
# i =2 , j=29, fin = 7, fout= 29
# i =2 , j=30, fin = 7, fout= 30
# i =2 , j=31, fin = 7, fout= 31
# i =2 , j=32, fin = 7, fout= 32
# i =2 , j=33, fin = 7, fout= 33
# i =2 , j=34, fin = 7, fout= 34
# i =2 , j=35, fin = 7, fout= 35
# i =2 , j=36, fin = 7, fout= 36
# i =2 , j=37, fin = 7, fout= 37
# i =2 , j=38, fin = 7, fout= 38
# i =2 , j=39, fin = 7, fout= 39
# i =2 , j=40, fin = 7, fout= 40
# i =2 , j=41, fin = 7, fout= 41
# i =2 , j=42, fin = 7, fout= 42
# i =2 , j=43, fin = 7, fout= 43
# i =2 , j=44, fin = 7, fout= 44
# i =2 , j=45, fin = 7, fout= 46
# i =2 , j=46, fin = 7, fout= 47
# i =2 , j=47, fin = 7, fout= 48
# i =2 , j=48, fin = 7, fout= 49
# i =2 , j=49, fin = 7, fout= 50
# i =2 , j=50, fin = 7, fout= 51
# i =2 , j=51, fin = 7, fout= 52
# i =2 , j=52, fin = 7, fout= 53
# i =2 , j=53, fin = 7, fout= 54
# i =2 , j=54, fin = 7, fout= 55
# i =2 , j=55, fin = 7, fout= 56
# i =2 , j=56, fin = 7, fout= 57
# i =2 , j=57, fin = 7, fout= 58
# i =2 , j=58, fin = 7, fout= 59
# i =2 , j=59, fin = 7, fout= 60
# i =2 , j=60, fin = 7, fout= 61
# i =2 , j=61, fin = 7, fout= 62
# i =2 , j=62, fin = 7, fout= 63
# i =2 , j=0, fin = 8, fout= 0
# i =2 , j=1, fin = 8, fout= 1
# i =2 , j=2, fin = 8, fout= 2
# i =2 , j=3, fin = 8, fout= 3
# i =2 , j=4, fin = 8, fout= 4
# i =2 , j=5, fin = 8, fout= 5
# i =2 , j=6, fin = 8, fout= 6
# i =2 , j=7, fin = 8, fout= 7
# i =2 , j=8, fin = 8, fout= 8
# i =2 , j=9, fin = 8, fout= 9
# i =2 , j=10, fin = 8, fout= 10
# i =2 , j=11, fin = 8, fout= 11
# i =2 , j=12, fin = 8, fout= 12
# i =2 , j=13, fin = 8, fout= 13
# i =2 , j=14, fin = 8, fout= 14
# i =2 , j=15, fin = 8, fout= 15
# i =2 , j=16, fin = 8, fout= 16
# i =2 , j=17, fin = 8, fout= 17
# i =2 , j=18, fin = 8, fout= 18
# i =2 , j=19, fin = 8, fout= 19
# i =2 , j=20, fin = 8, fout= 21
# i =2 , j=21, fin = 8, fout= 22
# i =2 , j=22, fin = 8, fout= 23
# i =2 , j=23, fin = 8, fout= 24
# i =2 , j=24, fin = 8, fout= 25
# i =2 , j=25, fin = 8, fout= 26
# i =2 , j=26, fin = 8, fout= 27
# i =2 , j=27, fin = 8, fout= 28
# i =2 , j=28, fin = 8, fout= 29
# i =2 , j=29, fin = 8, fout= 30
# i =2 , j=30, fin = 8, fout= 31
# i =2 , j=31, fin = 8, fout= 32
# i =2 , j=32, fin = 8, fout= 33
# i =2 , j=33, fin = 8, fout= 34
# i =2 , j=34, fin = 8, fout= 35
# i =2 , j=35, fin = 8, fout= 36
# i =2 , j=36, fin = 8, fout= 37
# i =2 , j=37, fin = 8, fout= 38
# i =2 , j=38, fin = 8, fout= 39
# i =2 , j=39, fin = 8, fout= 40
# i =2 , j=40, fin = 8, fout= 41
# i =2 , j=41, fin = 8, fout= 42
# i =2 , j=42, fin = 8, fout= 43
# i =2 , j=43, fin = 8, fout= 44
# i =2 , j=44, fin = 8, fout= 45
# i =2 , j=45, fin = 8, fout= 46
# i =2 , j=46, fin = 8, fout= 47
# i =2 , j=47, fin = 8, fout= 48
# i =2 , j=48, fin = 8, fout= 49
# i =2 , j=49, fin = 8, fout= 50
# i =2 , j=50, fin = 8, fout= 51
# i =2 , j=51, fin = 8, fout= 52
# i =2 , j=52, fin = 8, fout= 53
# i =2 , j=53, fin = 8, fout= 54
# i =2 , j=54, fin = 8, fout= 55
# i =2 , j=55, fin = 8, fout= 56
# i =2 , j=56, fin = 8, fout= 57
# i =2 , j=57, fin = 8, fout= 58
# i =2 , j=58, fin = 8, fout= 59
# i =2 , j=59, fin = 8, fout= 60
# i =2 , j=60, fin = 8, fout= 61
# i =2 , j=61, fin = 8, fout= 62
# i =2 , j=62, fin = 8, fout= 63
# i =2 , j=0, fin = 9, fout= 0
# i =2 , j=1, fin = 9, fout= 1
# i =2 , j=2, fin = 9, fout= 2
# i =2 , j=3, fin = 9, fout= 3
# i =2 , j=4, fin = 9, fout= 4
# i =2 , j=5, fin = 9, fout= 5
# i =2 , j=6, fin = 9, fout= 6
# i =2 , j=7, fin = 9, fout= 7
# i =2 , j=8, fin = 9, fout= 8
# i =2 , j=9, fin = 9, fout= 9
# i =2 , j=10, fin = 9, fout= 10
# i =2 , j=11, fin = 9, fout= 11
# i =2 , j=12, fin = 9, fout= 12
# i =2 , j=13, fin = 9, fout= 13
# i =2 , j=14, fin = 9, fout= 14
# i =2 , j=15, fin = 9, fout= 15
# i =2 , j=16, fin = 9, fout= 16
# i =2 , j=17, fin = 9, fout= 17
# i =2 , j=18, fin = 9, fout= 18
# i =2 , j=19, fin = 9, fout= 19
# i =2 , j=20, fin = 9, fout= 20
# i =2 , j=21, fin = 9, fout= 21
# i =2 , j=22, fin = 9, fout= 22
# i =2 , j=23, fin = 9, fout= 23
# i =2 , j=24, fin = 9, fout= 24
# i =2 , j=25, fin = 9, fout= 25
# i =2 , j=26, fin = 9, fout= 26
# i =2 , j=27, fin = 9, fout= 27
# i =2 , j=28, fin = 9, fout= 28
# i =2 , j=29, fin = 9, fout= 29
# i =2 , j=30, fin = 9, fout= 30
# i =2 , j=31, fin = 9, fout= 31
# i =2 , j=32, fin = 9, fout= 33
# i =2 , j=33, fin = 9, fout= 34
# i =2 , j=34, fin = 9, fout= 35
# i =2 , j=35, fin = 9, fout= 36
# i =2 , j=36, fin = 9, fout= 37
# i =2 , j=37, fin = 9, fout= 38
# i =2 , j=38, fin = 9, fout= 39
# i =2 , j=39, fin = 9, fout= 40
# i =2 , j=40, fin = 9, fout= 41
# i =2 , j=41, fin = 9, fout= 42
# i =2 , j=42, fin = 9, fout= 43
# i =2 , j=43, fin = 9, fout= 44
# i =2 , j=44, fin = 9, fout= 45
# i =2 , j=45, fin = 9, fout= 46
# i =2 , j=46, fin = 9, fout= 47
# i =2 , j=47, fin = 9, fout= 48
# i =2 , j=48, fin = 9, fout= 49
# i =2 , j=49, fin = 9, fout= 50
# i =2 , j=50, fin = 9, fout= 51
# i =2 , j=51, fin = 9, fout= 52
# i =2 , j=52, fin = 9, fout= 53
# i =2 , j=53, fin = 9, fout= 54
# i =2 , j=54, fin = 9, fout= 55
# i =2 , j=55, fin = 9, fout= 56
# i =2 , j=56, fin = 9, fout= 57
# i =2 , j=57, fin = 9, fout= 58
# i =2 , j=58, fin = 9, fout= 59
# i =2 , j=59, fin = 9, fout= 60
# i =2 , j=60, fin = 9, fout= 61
# i =2 , j=61, fin = 9, fout= 62
# i =2 , j=62, fin = 9, fout= 63
# i =2 , j=0, fin = 10, fout= 0
# i =2 , j=1, fin = 10, fout= 1
# i =2 , j=2, fin = 10, fout= 2
# i =2 , j=3, fin = 10, fout= 3
# i =2 , j=4, fin = 10, fout= 4
# i =2 , j=5, fin = 10, fout= 5
# i =2 , j=6, fin = 10, fout= 6
# i =2 , j=7, fin = 10, fout= 7
# i =2 , j=8, fin = 10, fout= 8
# i =2 , j=9, fin = 10, fout= 9
# i =2 , j=10, fin = 10, fout= 10
# i =2 , j=11, fin = 10, fout= 11
# i =2 , j=12, fin = 10, fout= 12
# i =2 , j=13, fin = 10, fout= 13
# i =2 , j=14, fin = 10, fout= 14
# i =2 , j=15, fin = 10, fout= 15
# i =2 , j=16, fin = 10, fout= 17
# i =2 , j=17, fin = 10, fout= 18
# i =2 , j=18, fin = 10, fout= 19
# i =2 , j=19, fin = 10, fout= 20
# i =2 , j=20, fin = 10, fout= 21
# i =2 , j=21, fin = 10, fout= 22
# i =2 , j=22, fin = 10, fout= 23
# i =2 , j=23, fin = 10, fout= 24
# i =2 , j=24, fin = 10, fout= 25
# i =2 , j=25, fin = 10, fout= 26
# i =2 , j=26, fin = 10, fout= 27
# i =2 , j=27, fin = 10, fout= 28
# i =2 , j=28, fin = 10, fout= 29
# i =2 , j=29, fin = 10, fout= 30
# i =2 , j=30, fin = 10, fout= 31
# i =2 , j=31, fin = 10, fout= 32
# i =2 , j=32, fin = 10, fout= 33
# i =2 , j=33, fin = 10, fout= 34
# i =2 , j=34, fin = 10, fout= 35
# i =2 , j=35, fin = 10, fout= 36
# i =2 , j=36, fin = 10, fout= 37
# i =2 , j=37, fin = 10, fout= 38
# i =2 , j=38, fin = 10, fout= 39
# i =2 , j=39, fin = 10, fout= 40
# i =2 , j=40, fin = 10, fout= 41
# i =2 , j=41, fin = 10, fout= 42
# i =2 , j=42, fin = 10, fout= 43
# i =2 , j=43, fin = 10, fout= 44
# i =2 , j=44, fin = 10, fout= 45
# i =2 , j=45, fin = 10, fout= 46
# i =2 , j=46, fin = 10, fout= 47
# i =2 , j=47, fin = 10, fout= 48
# i =2 , j=48, fin = 10, fout= 49
# i =2 , j=49, fin = 10, fout= 50
# i =2 , j=50, fin = 10, fout= 51
# i =2 , j=51, fin = 10, fout= 52
# i =2 , j=52, fin = 10, fout= 53
# i =2 , j=53, fin = 10, fout= 54
# i =2 , j=54, fin = 10, fout= 55
# i =2 , j=55, fin = 10, fout= 56
# i =2 , j=56, fin = 10, fout= 57
# i =2 , j=57, fin = 10, fout= 58
# i =2 , j=58, fin = 10, fout= 59
# i =2 , j=59, fin = 10, fout= 60
# i =2 , j=60, fin = 10, fout= 61
# i =2 , j=61, fin = 10, fout= 62
# i =2 , j=62, fin = 10, fout= 63
# i =2 , j=0, fin = 11, fout= 0
# i =2 , j=1, fin = 11, fout= 1
# i =2 , j=2, fin = 11, fout= 2
# i =2 , j=3, fin = 11, fout= 3
# i =2 , j=4, fin = 11, fout= 4
# i =2 , j=5, fin = 11, fout= 5
# i =2 , j=6, fin = 11, fout= 6
# i =2 , j=7, fin = 11, fout= 7
# i =2 , j=8, fin = 11, fout= 8
# i =2 , j=9, fin = 11, fout= 9
# i =2 , j=10, fin = 11, fout= 10
# i =2 , j=11, fin = 11, fout= 11
# i =2 , j=12, fin = 11, fout= 12
# i =2 , j=13, fin = 11, fout= 13
# i =2 , j=14, fin = 11, fout= 14
# i =2 , j=15, fin = 11, fout= 15
# i =2 , j=16, fin = 11, fout= 16
# i =2 , j=17, fin = 11, fout= 17
# i =2 , j=18, fin = 11, fout= 18
# i =2 , j=19, fin = 11, fout= 19
# i =2 , j=20, fin = 11, fout= 20
# i =2 , j=21, fin = 11, fout= 21
# i =2 , j=22, fin = 11, fout= 22
# i =2 , j=23, fin = 11, fout= 23
# i =2 , j=24, fin = 11, fout= 24
# i =2 , j=25, fin = 11, fout= 25
# i =2 , j=26, fin = 11, fout= 26
# i =2 , j=27, fin = 11, fout= 27
# i =2 , j=28, fin = 11, fout= 28
# i =2 , j=29, fin = 11, fout= 29
# i =2 , j=30, fin = 11, fout= 30
# i =2 , j=31, fin = 11, fout= 31
# i =2 , j=32, fin = 11, fout= 32
# i =2 , j=33, fin = 11, fout= 33
# i =2 , j=34, fin = 11, fout= 34
# i =2 , j=35, fin = 11, fout= 35
# i =2 , j=36, fin = 11, fout= 36
# i =2 , j=37, fin = 11, fout= 37
# i =2 , j=38, fin = 11, fout= 38
# i =2 , j=39, fin = 11, fout= 39
# i =2 , j=40, fin = 11, fout= 40
# i =2 , j=41, fin = 11, fout= 41
# i =2 , j=42, fin = 11, fout= 42
# i =2 , j=43, fin = 11, fout= 43
# i =2 , j=44, fin = 11, fout= 44
# i =2 , j=45, fin = 11, fout= 45
# i =2 , j=46, fin = 11, fout= 47
# i =2 , j=47, fin = 11, fout= 48
# i =2 , j=48, fin = 11, fout= 49
# i =2 , j=49, fin = 11, fout= 50
# i =2 , j=50, fin = 11, fout= 51
# i =2 , j=51, fin = 11, fout= 52
# i =2 , j=52, fin = 11, fout= 53
# i =2 , j=53, fin = 11, fout= 54
# i =2 , j=54, fin = 11, fout= 55
# i =2 , j=55, fin = 11, fout= 56
# i =2 , j=56, fin = 11, fout= 57
# i =2 , j=57, fin = 11, fout= 58
# i =2 , j=58, fin = 11, fout= 59
# i =2 , j=59, fin = 11, fout= 60
# i =2 , j=60, fin = 11, fout= 61
# i =2 , j=61, fin = 11, fout= 62
# i =2 , j=62, fin = 11, fout= 63
# i =2 , j=0, fin = 12, fout= 0
# i =2 , j=1, fin = 12, fout= 1
# i =2 , j=2, fin = 12, fout= 2
# i =2 , j=3, fin = 12, fout= 3
# i =2 , j=4, fin = 12, fout= 4
# i =2 , j=5, fin = 12, fout= 5
# i =2 , j=6, fin = 12, fout= 6
# i =2 , j=7, fin = 12, fout= 7
# i =2 , j=8, fin = 12, fout= 8
# i =2 , j=9, fin = 12, fout= 9
# i =2 , j=10, fin = 12, fout= 10
# i =2 , j=11, fin = 12, fout= 12
# i =2 , j=12, fin = 12, fout= 13
# i =2 , j=13, fin = 12, fout= 14
# i =2 , j=14, fin = 12, fout= 15
# i =2 , j=15, fin = 12, fout= 16
# i =2 , j=16, fin = 12, fout= 17
# i =2 , j=17, fin = 12, fout= 18
# i =2 , j=18, fin = 12, fout= 19
# i =2 , j=19, fin = 12, fout= 20
# i =2 , j=20, fin = 12, fout= 21
# i =2 , j=21, fin = 12, fout= 22
# i =2 , j=22, fin = 12, fout= 23
# i =2 , j=23, fin = 12, fout= 24
# i =2 , j=24, fin = 12, fout= 25
# i =2 , j=25, fin = 12, fout= 26
# i =2 , j=26, fin = 12, fout= 27
# i =2 , j=27, fin = 12, fout= 28
# i =2 , j=28, fin = 12, fout= 29
# i =2 , j=29, fin = 12, fout= 30
# i =2 , j=30, fin = 12, fout= 31
# i =2 , j=31, fin = 12, fout= 32
# i =2 , j=32, fin = 12, fout= 33
# i =2 , j=33, fin = 12, fout= 34
# i =2 , j=34, fin = 12, fout= 35
# i =2 , j=35, fin = 12, fout= 36
# i =2 , j=36, fin = 12, fout= 37
# i =2 , j=37, fin = 12, fout= 38
# i =2 , j=38, fin = 12, fout= 39
# i =2 , j=39, fin = 12, fout= 40
# i =2 , j=40, fin = 12, fout= 41
# i =2 , j=41, fin = 12, fout= 42
# i =2 , j=42, fin = 12, fout= 43
# i =2 , j=43, fin = 12, fout= 44
# i =2 , j=44, fin = 12, fout= 45
# i =2 , j=45, fin = 12, fout= 46
# i =2 , j=46, fin = 12, fout= 47
# i =2 , j=47, fin = 12, fout= 48
# i =2 , j=48, fin = 12, fout= 49
# i =2 , j=49, fin = 12, fout= 50
# i =2 , j=50, fin = 12, fout= 51
# i =2 , j=51, fin = 12, fout= 52
# i =2 , j=52, fin = 12, fout= 53
# i =2 , j=53, fin = 12, fout= 54
# i =2 , j=54, fin = 12, fout= 55
# i =2 , j=55, fin = 12, fout= 56
# i =2 , j=56, fin = 12, fout= 57
# i =2 , j=57, fin = 12, fout= 58
# i =2 , j=58, fin = 12, fout= 59
# i =2 , j=59, fin = 12, fout= 60
# i =2 , j=60, fin = 12, fout= 61
# i =2 , j=61, fin = 12, fout= 62
# i =2 , j=62, fin = 12, fout= 63
# i =2 , j=0, fin = 13, fout= 0
# i =2 , j=1, fin = 13, fout= 1
# i =2 , j=2, fin = 13, fout= 2
# i =2 , j=3, fin = 13, fout= 3
# i =2 , j=4, fin = 13, fout= 4
# i =2 , j=5, fin = 13, fout= 5
# i =2 , j=6, fin = 13, fout= 6
# i =2 , j=7, fin = 13, fout= 8
# i =2 , j=8, fin = 13, fout= 9
# i =2 , j=9, fin = 13, fout= 10
# i =2 , j=10, fin = 13, fout= 11
# i =2 , j=11, fin = 13, fout= 12
# i =2 , j=12, fin = 13, fout= 13
# i =2 , j=13, fin = 13, fout= 14
# i =2 , j=14, fin = 13, fout= 15
# i =2 , j=15, fin = 13, fout= 16
# i =2 , j=16, fin = 13, fout= 17
# i =2 , j=17, fin = 13, fout= 18
# i =2 , j=18, fin = 13, fout= 19
# i =2 , j=19, fin = 13, fout= 20
# i =2 , j=20, fin = 13, fout= 21
# i =2 , j=21, fin = 13, fout= 22
# i =2 , j=22, fin = 13, fout= 23
# i =2 , j=23, fin = 13, fout= 24
# i =2 , j=24, fin = 13, fout= 25
# i =2 , j=25, fin = 13, fout= 26
# i =2 , j=26, fin = 13, fout= 27
# i =2 , j=27, fin = 13, fout= 28
# i =2 , j=28, fin = 13, fout= 29
# i =2 , j=29, fin = 13, fout= 30
# i =2 , j=30, fin = 13, fout= 31
# i =2 , j=31, fin = 13, fout= 32
# i =2 , j=32, fin = 13, fout= 33
# i =2 , j=33, fin = 13, fout= 34
# i =2 , j=34, fin = 13, fout= 35
# i =2 , j=35, fin = 13, fout= 36
# i =2 , j=36, fin = 13, fout= 37
# i =2 , j=37, fin = 13, fout= 38
# i =2 , j=38, fin = 13, fout= 39
# i =2 , j=39, fin = 13, fout= 40
# i =2 , j=40, fin = 13, fout= 41
# i =2 , j=41, fin = 13, fout= 42
# i =2 , j=42, fin = 13, fout= 43
# i =2 , j=43, fin = 13, fout= 44
# i =2 , j=44, fin = 13, fout= 45
# i =2 , j=45, fin = 13, fout= 46
# i =2 , j=46, fin = 13, fout= 47
# i =2 , j=47, fin = 13, fout= 48
# i =2 , j=48, fin = 13, fout= 49
# i =2 , j=49, fin = 13, fout= 50
# i =2 , j=50, fin = 13, fout= 51
# i =2 , j=51, fin = 13, fout= 52
# i =2 , j=52, fin = 13, fout= 53
# i =2 , j=53, fin = 13, fout= 54
# i =2 , j=54, fin = 13, fout= 55
# i =2 , j=55, fin = 13, fout= 56
# i =2 , j=56, fin = 13, fout= 57
# i =2 , j=57, fin = 13, fout= 58
# i =2 , j=58, fin = 13, fout= 59
# i =2 , j=59, fin = 13, fout= 60
# i =2 , j=60, fin = 13, fout= 61
# i =2 , j=61, fin = 13, fout= 62
# i =2 , j=62, fin = 13, fout= 63
# i =2 , j=0, fin = 14, fout= 0
# i =2 , j=1, fin = 14, fout= 1
# i =2 , j=2, fin = 14, fout= 2
# i =2 , j=3, fin = 14, fout= 3
# i =2 , j=4, fin = 14, fout= 4
# i =2 , j=5, fin = 14, fout= 5
# i =2 , j=6, fin = 14, fout= 6
# i =2 , j=7, fin = 14, fout= 7
# i =2 , j=8, fin = 14, fout= 8
# i =2 , j=9, fin = 14, fout= 9
# i =2 , j=10, fin = 14, fout= 10
# i =2 , j=11, fin = 14, fout= 11
# i =2 , j=12, fin = 14, fout= 12
# i =2 , j=13, fin = 14, fout= 14
# i =2 , j=14, fin = 14, fout= 15
# i =2 , j=15, fin = 14, fout= 16
# i =2 , j=16, fin = 14, fout= 17
# i =2 , j=17, fin = 14, fout= 18
# i =2 , j=18, fin = 14, fout= 19
# i =2 , j=19, fin = 14, fout= 20
# i =2 , j=20, fin = 14, fout= 21
# i =2 , j=21, fin = 14, fout= 22
# i =2 , j=22, fin = 14, fout= 23
# i =2 , j=23, fin = 14, fout= 24
# i =2 , j=24, fin = 14, fout= 25
# i =2 , j=25, fin = 14, fout= 26
# i =2 , j=26, fin = 14, fout= 27
# i =2 , j=27, fin = 14, fout= 28
# i =2 , j=28, fin = 14, fout= 29
# i =2 , j=29, fin = 14, fout= 30
# i =2 , j=30, fin = 14, fout= 31
# i =2 , j=31, fin = 14, fout= 32
# i =2 , j=32, fin = 14, fout= 33
# i =2 , j=33, fin = 14, fout= 34
# i =2 , j=34, fin = 14, fout= 35
# i =2 , j=35, fin = 14, fout= 36
# i =2 , j=36, fin = 14, fout= 37
# i =2 , j=37, fin = 14, fout= 38
# i =2 , j=38, fin = 14, fout= 39
# i =2 , j=39, fin = 14, fout= 40
# i =2 , j=40, fin = 14, fout= 41
# i =2 , j=41, fin = 14, fout= 42
# i =2 , j=42, fin = 14, fout= 43
# i =2 , j=43, fin = 14, fout= 44
# i =2 , j=44, fin = 14, fout= 45
# i =2 , j=45, fin = 14, fout= 46
# i =2 , j=46, fin = 14, fout= 47
# i =2 , j=47, fin = 14, fout= 48
# i =2 , j=48, fin = 14, fout= 49
# i =2 , j=49, fin = 14, fout= 50
# i =2 , j=50, fin = 14, fout= 51
# i =2 , j=51, fin = 14, fout= 52
# i =2 , j=52, fin = 14, fout= 53
# i =2 , j=53, fin = 14, fout= 54
# i =2 , j=54, fin = 14, fout= 55
# i =2 , j=55, fin = 14, fout= 56
# i =2 , j=56, fin = 14, fout= 57
# i =2 , j=57, fin = 14, fout= 58
# i =2 , j=58, fin = 14, fout= 59
# i =2 , j=59, fin = 14, fout= 60
# i =2 , j=60, fin = 14, fout= 61
# i =2 , j=61, fin = 14, fout= 62
# i =2 , j=62, fin = 14, fout= 63
# i =2 , j=0, fin = 15, fout= 0
# i =2 , j=1, fin = 15, fout= 1
# i =2 , j=2, fin = 15, fout= 2
# i =2 , j=3, fin = 15, fout= 3
# i =2 , j=4, fin = 15, fout= 4
# i =2 , j=5, fin = 15, fout= 5
# i =2 , j=6, fin = 15, fout= 6
# i =2 , j=7, fin = 15, fout= 7
# i =2 , j=8, fin = 15, fout= 8
# i =2 , j=9, fin = 15, fout= 9
# i =2 , j=10, fin = 15, fout= 10
# i =2 , j=11, fin = 15, fout= 11
# i =2 , j=12, fin = 15, fout= 12
# i =2 , j=13, fin = 15, fout= 13
# i =2 , j=14, fin = 15, fout= 14
# i =2 , j=15, fin = 15, fout= 15
# i =2 , j=16, fin = 15, fout= 16
# i =2 , j=17, fin = 15, fout= 17
# i =2 , j=18, fin = 15, fout= 18
# i =2 , j=19, fin = 15, fout= 19
# i =2 , j=20, fin = 15, fout= 20
# i =2 , j=21, fin = 15, fout= 21
# i =2 , j=22, fin = 15, fout= 22
# i =2 , j=23, fin = 15, fout= 23
# i =2 , j=24, fin = 15, fout= 24
# i =2 , j=25, fin = 15, fout= 25
# i =2 , j=26, fin = 15, fout= 26
# i =2 , j=27, fin = 15, fout= 27
# i =2 , j=28, fin = 15, fout= 28
# i =2 , j=29, fin = 15, fout= 29
# i =2 , j=30, fin = 15, fout= 30
# i =2 , j=31, fin = 15, fout= 31
# i =2 , j=32, fin = 15, fout= 32
# i =2 , j=33, fin = 15, fout= 33
# i =2 , j=34, fin = 15, fout= 35
# i =2 , j=35, fin = 15, fout= 36
# i =2 , j=36, fin = 15, fout= 37
# i =2 , j=37, fin = 15, fout= 38
# i =2 , j=38, fin = 15, fout= 39
# i =2 , j=39, fin = 15, fout= 40
# i =2 , j=40, fin = 15, fout= 41
# i =2 , j=41, fin = 15, fout= 42
# i =2 , j=42, fin = 15, fout= 43
# i =2 , j=43, fin = 15, fout= 44
# i =2 , j=44, fin = 15, fout= 45
# i =2 , j=45, fin = 15, fout= 46
# i =2 , j=46, fin = 15, fout= 47
# i =2 , j=47, fin = 15, fout= 48
# i =2 , j=48, fin = 15, fout= 49
# i =2 , j=49, fin = 15, fout= 50
# i =2 , j=50, fin = 15, fout= 51
# i =2 , j=51, fin = 15, fout= 52
# i =2 , j=52, fin = 15, fout= 53
# i =2 , j=53, fin = 15, fout= 54
# i =2 , j=54, fin = 15, fout= 55
# i =2 , j=55, fin = 15, fout= 56
# i =2 , j=56, fin = 15, fout= 57
# i =2 , j=57, fin = 15, fout= 58
# i =2 , j=58, fin = 15, fout= 59
# i =2 , j=59, fin = 15, fout= 60
# i =2 , j=60, fin = 15, fout= 61
# i =2 , j=61, fin = 15, fout= 62
# i =2 , j=62, fin = 15, fout= 63
# i =2 , j=0, fin = 16, fout= 0
# i =2 , j=1, fin = 16, fout= 1
# i =2 , j=2, fin = 16, fout= 2
# i =2 , j=3, fin = 16, fout= 3
# i =2 , j=4, fin = 16, fout= 4
# i =2 , j=5, fin = 16, fout= 5
# i =2 , j=6, fin = 16, fout= 6
# i =2 , j=7, fin = 16, fout= 7
# i =2 , j=8, fin = 16, fout= 8
# i =2 , j=9, fin = 16, fout= 9
# i =2 , j=10, fin = 16, fout= 10
# i =2 , j=11, fin = 16, fout= 11
# i =2 , j=12, fin = 16, fout= 12
# i =2 , j=13, fin = 16, fout= 13
# i =2 , j=14, fin = 16, fout= 14
# i =2 , j=15, fin = 16, fout= 16
# i =2 , j=16, fin = 16, fout= 17
# i =2 , j=17, fin = 16, fout= 18
# i =2 , j=18, fin = 16, fout= 19
# i =2 , j=19, fin = 16, fout= 20
# i =2 , j=20, fin = 16, fout= 21
# i =2 , j=21, fin = 16, fout= 22
# i =2 , j=22, fin = 16, fout= 23
# i =2 , j=23, fin = 16, fout= 24
# i =2 , j=24, fin = 16, fout= 25
# i =2 , j=25, fin = 16, fout= 26
# i =2 , j=26, fin = 16, fout= 27
# i =2 , j=27, fin = 16, fout= 28
# i =2 , j=28, fin = 16, fout= 29
# i =2 , j=29, fin = 16, fout= 30
# i =2 , j=30, fin = 16, fout= 31
# i =2 , j=31, fin = 16, fout= 32
# i =2 , j=32, fin = 16, fout= 33
# i =2 , j=33, fin = 16, fout= 34
# i =2 , j=34, fin = 16, fout= 35
# i =2 , j=35, fin = 16, fout= 36
# i =2 , j=36, fin = 16, fout= 37
# i =2 , j=37, fin = 16, fout= 38
# i =2 , j=38, fin = 16, fout= 39
# i =2 , j=39, fin = 16, fout= 40
# i =2 , j=40, fin = 16, fout= 41
# i =2 , j=41, fin = 16, fout= 42
# i =2 , j=42, fin = 16, fout= 43
# i =2 , j=43, fin = 16, fout= 44
# i =2 , j=44, fin = 16, fout= 45
# i =2 , j=45, fin = 16, fout= 46
# i =2 , j=46, fin = 16, fout= 47
# i =2 , j=47, fin = 16, fout= 48
# i =2 , j=48, fin = 16, fout= 49
# i =2 , j=49, fin = 16, fout= 50
# i =2 , j=50, fin = 16, fout= 51
# i =2 , j=51, fin = 16, fout= 52
# i =2 , j=52, fin = 16, fout= 53
# i =2 , j=53, fin = 16, fout= 54
# i =2 , j=54, fin = 16, fout= 55
# i =2 , j=55, fin = 16, fout= 56
# i =2 , j=56, fin = 16, fout= 57
# i =2 , j=57, fin = 16, fout= 58
# i =2 , j=58, fin = 16, fout= 59
# i =2 , j=59, fin = 16, fout= 60
# i =2 , j=60, fin = 16, fout= 61
# i =2 , j=61, fin = 16, fout= 62
# i =2 , j=62, fin = 16, fout= 63
# i =2 , j=0, fin = 17, fout= 0
# i =2 , j=1, fin = 17, fout= 1
# i =2 , j=2, fin = 17, fout= 2
# i =2 , j=3, fin = 17, fout= 3
# i =2 , j=4, fin = 17, fout= 4
# i =2 , j=5, fin = 17, fout= 5
# i =2 , j=6, fin = 17, fout= 6
# i =2 , j=7, fin = 17, fout= 7
# i =2 , j=8, fin = 17, fout= 8
# i =2 , j=9, fin = 17, fout= 9
# i =2 , j=10, fin = 17, fout= 10
# i =2 , j=11, fin = 17, fout= 11
# i =2 , j=12, fin = 17, fout= 12
# i =2 , j=13, fin = 17, fout= 13
# i =2 , j=14, fin = 17, fout= 14
# i =2 , j=15, fin = 17, fout= 15
# i =2 , j=16, fin = 17, fout= 16
# i =2 , j=17, fin = 17, fout= 17
# i =2 , j=18, fin = 17, fout= 18
# i =2 , j=19, fin = 17, fout= 20
# i =2 , j=20, fin = 17, fout= 21
# i =2 , j=21, fin = 17, fout= 22
# i =2 , j=22, fin = 17, fout= 23
# i =2 , j=23, fin = 17, fout= 24
# i =2 , j=24, fin = 17, fout= 25
# i =2 , j=25, fin = 17, fout= 26
# i =2 , j=26, fin = 17, fout= 27
# i =2 , j=27, fin = 17, fout= 28
# i =2 , j=28, fin = 17, fout= 29
# i =2 , j=29, fin = 17, fout= 30
# i =2 , j=30, fin = 17, fout= 31
# i =2 , j=31, fin = 17, fout= 32
# i =2 , j=32, fin = 17, fout= 33
# i =2 , j=33, fin = 17, fout= 34
# i =2 , j=34, fin = 17, fout= 35
# i =2 , j=35, fin = 17, fout= 36
# i =2 , j=36, fin = 17, fout= 37
# i =2 , j=37, fin = 17, fout= 38
# i =2 , j=38, fin = 17, fout= 39
# i =2 , j=39, fin = 17, fout= 40
# i =2 , j=40, fin = 17, fout= 41
# i =2 , j=41, fin = 17, fout= 42
# i =2 , j=42, fin = 17, fout= 43
# i =2 , j=43, fin = 17, fout= 44
# i =2 , j=44, fin = 17, fout= 45
# i =2 , j=45, fin = 17, fout= 46
# i =2 , j=46, fin = 17, fout= 47
# i =2 , j=47, fin = 17, fout= 48
# i =2 , j=48, fin = 17, fout= 49
# i =2 , j=49, fin = 17, fout= 50
# i =2 , j=50, fin = 17, fout= 51
# i =2 , j=51, fin = 17, fout= 52
# i =2 , j=52, fin = 17, fout= 53
# i =2 , j=53, fin = 17, fout= 54
# i =2 , j=54, fin = 17, fout= 55
# i =2 , j=55, fin = 17, fout= 56
# i =2 , j=56, fin = 17, fout= 57
# i =2 , j=57, fin = 17, fout= 58
# i =2 , j=58, fin = 17, fout= 59
# i =2 , j=59, fin = 17, fout= 60
# i =2 , j=60, fin = 17, fout= 61
# i =2 , j=61, fin = 17, fout= 62
# i =2 , j=62, fin = 17, fout= 63
# i =2 , j=0, fin = 18, fout= 0
# i =2 , j=1, fin = 18, fout= 1
# i =2 , j=2, fin = 18, fout= 2
# i =2 , j=3, fin = 18, fout= 3
# i =2 , j=4, fin = 18, fout= 4
# i =2 , j=5, fin = 18, fout= 5
# i =2 , j=6, fin = 18, fout= 6
# i =2 , j=7, fin = 18, fout= 7
# i =2 , j=8, fin = 18, fout= 8
# i =2 , j=9, fin = 18, fout= 9
# i =2 , j=10, fin = 18, fout= 10
# i =2 , j=11, fin = 18, fout= 11
# i =2 , j=12, fin = 18, fout= 12
# i =2 , j=13, fin = 18, fout= 13
# i =2 , j=14, fin = 18, fout= 14
# i =2 , j=15, fin = 18, fout= 15
# i =2 , j=16, fin = 18, fout= 16
# i =2 , j=17, fin = 18, fout= 17
# i =2 , j=18, fin = 18, fout= 18
# i =2 , j=19, fin = 18, fout= 19
# i =2 , j=20, fin = 18, fout= 20
# i =2 , j=21, fin = 18, fout= 21
# i =2 , j=22, fin = 18, fout= 23
# i =2 , j=23, fin = 18, fout= 24
# i =2 , j=24, fin = 18, fout= 25
# i =2 , j=25, fin = 18, fout= 26
# i =2 , j=26, fin = 18, fout= 27
# i =2 , j=27, fin = 18, fout= 28
# i =2 , j=28, fin = 18, fout= 29
# i =2 , j=29, fin = 18, fout= 30
# i =2 , j=30, fin = 18, fout= 31
# i =2 , j=31, fin = 18, fout= 32
# i =2 , j=32, fin = 18, fout= 33
# i =2 , j=33, fin = 18, fout= 34
# i =2 , j=34, fin = 18, fout= 35
# i =2 , j=35, fin = 18, fout= 36
# i =2 , j=36, fin = 18, fout= 37
# i =2 , j=37, fin = 18, fout= 38
# i =2 , j=38, fin = 18, fout= 39
# i =2 , j=39, fin = 18, fout= 40
# i =2 , j=40, fin = 18, fout= 41
# i =2 , j=41, fin = 18, fout= 42
# i =2 , j=42, fin = 18, fout= 43
# i =2 , j=43, fin = 18, fout= 44
# i =2 , j=44, fin = 18, fout= 45
# i =2 , j=45, fin = 18, fout= 46
# i =2 , j=46, fin = 18, fout= 47
# i =2 , j=47, fin = 18, fout= 48
# i =2 , j=48, fin = 18, fout= 49
# i =2 , j=49, fin = 18, fout= 50
# i =2 , j=50, fin = 18, fout= 51
# i =2 , j=51, fin = 18, fout= 52
# i =2 , j=52, fin = 18, fout= 53
# i =2 , j=53, fin = 18, fout= 54
# i =2 , j=54, fin = 18, fout= 55
# i =2 , j=55, fin = 18, fout= 56
# i =2 , j=56, fin = 18, fout= 57
# i =2 , j=57, fin = 18, fout= 58
# i =2 , j=58, fin = 18, fout= 59
# i =2 , j=59, fin = 18, fout= 60
# i =2 , j=60, fin = 18, fout= 61
# i =2 , j=61, fin = 18, fout= 62
# i =2 , j=62, fin = 18, fout= 63
# i =2 , j=0, fin = 19, fout= 0
# i =2 , j=1, fin = 19, fout= 1
# i =2 , j=2, fin = 19, fout= 2
# i =2 , j=3, fin = 19, fout= 3
# i =2 , j=4, fin = 19, fout= 4
# i =2 , j=5, fin = 19, fout= 5
# i =2 , j=6, fin = 19, fout= 6
# i =2 , j=7, fin = 19, fout= 7
# i =2 , j=8, fin = 19, fout= 8
# i =2 , j=9, fin = 19, fout= 9
# i =2 , j=10, fin = 19, fout= 10
# i =2 , j=11, fin = 19, fout= 11
# i =2 , j=12, fin = 19, fout= 12
# i =2 , j=13, fin = 19, fout= 13
# i =2 , j=14, fin = 19, fout= 14
# i =2 , j=15, fin = 19, fout= 15
# i =2 , j=16, fin = 19, fout= 16
# i =2 , j=17, fin = 19, fout= 17
# i =2 , j=18, fin = 19, fout= 18
# i =2 , j=19, fin = 19, fout= 20
# i =2 , j=20, fin = 19, fout= 21
# i =2 , j=21, fin = 19, fout= 22
# i =2 , j=22, fin = 19, fout= 23
# i =2 , j=23, fin = 19, fout= 24
# i =2 , j=24, fin = 19, fout= 25
# i =2 , j=25, fin = 19, fout= 26
# i =2 , j=26, fin = 19, fout= 27
# i =2 , j=27, fin = 19, fout= 28
# i =2 , j=28, fin = 19, fout= 29
# i =2 , j=29, fin = 19, fout= 30
# i =2 , j=30, fin = 19, fout= 31
# i =2 , j=31, fin = 19, fout= 32
# i =2 , j=32, fin = 19, fout= 33
# i =2 , j=33, fin = 19, fout= 34
# i =2 , j=34, fin = 19, fout= 35
# i =2 , j=35, fin = 19, fout= 36
# i =2 , j=36, fin = 19, fout= 37
# i =2 , j=37, fin = 19, fout= 38
# i =2 , j=38, fin = 19, fout= 39
# i =2 , j=39, fin = 19, fout= 40
# i =2 , j=40, fin = 19, fout= 41
# i =2 , j=41, fin = 19, fout= 42
# i =2 , j=42, fin = 19, fout= 43
# i =2 , j=43, fin = 19, fout= 44
# i =2 , j=44, fin = 19, fout= 45
# i =2 , j=45, fin = 19, fout= 46
# i =2 , j=46, fin = 19, fout= 47
# i =2 , j=47, fin = 19, fout= 48
# i =2 , j=48, fin = 19, fout= 49
# i =2 , j=49, fin = 19, fout= 50
# i =2 , j=50, fin = 19, fout= 51
# i =2 , j=51, fin = 19, fout= 52
# i =2 , j=52, fin = 19, fout= 53
# i =2 , j=53, fin = 19, fout= 54
# i =2 , j=54, fin = 19, fout= 55
# i =2 , j=55, fin = 19, fout= 56
# i =2 , j=56, fin = 19, fout= 57
# i =2 , j=57, fin = 19, fout= 58
# i =2 , j=58, fin = 19, fout= 59
# i =2 , j=59, fin = 19, fout= 60
# i =2 , j=60, fin = 19, fout= 61
# i =2 , j=61, fin = 19, fout= 62
# i =2 , j=62, fin = 19, fout= 63
# i =2 , j=0, fin = 20, fout= 0
# i =2 , j=1, fin = 20, fout= 1
# i =2 , j=2, fin = 20, fout= 2
# i =2 , j=3, fin = 20, fout= 3
# i =2 , j=4, fin = 20, fout= 4
# i =2 , j=5, fin = 20, fout= 5
# i =2 , j=6, fin = 20, fout= 6
# i =2 , j=7, fin = 20, fout= 7
# i =2 , j=8, fin = 20, fout= 8
# i =2 , j=9, fin = 20, fout= 9
# i =2 , j=10, fin = 20, fout= 11
# i =2 , j=11, fin = 20, fout= 12
# i =2 , j=12, fin = 20, fout= 13
# i =2 , j=13, fin = 20, fout= 14
# i =2 , j=14, fin = 20, fout= 15
# i =2 , j=15, fin = 20, fout= 16
# i =2 , j=16, fin = 20, fout= 17
# i =2 , j=17, fin = 20, fout= 18
# i =2 , j=18, fin = 20, fout= 19
# i =2 , j=19, fin = 20, fout= 20
# i =2 , j=20, fin = 20, fout= 21
# i =2 , j=21, fin = 20, fout= 22
# i =2 , j=22, fin = 20, fout= 23
# i =2 , j=23, fin = 20, fout= 24
# i =2 , j=24, fin = 20, fout= 25
# i =2 , j=25, fin = 20, fout= 26
# i =2 , j=26, fin = 20, fout= 27
# i =2 , j=27, fin = 20, fout= 28
# i =2 , j=28, fin = 20, fout= 29
# i =2 , j=29, fin = 20, fout= 30
# i =2 , j=30, fin = 20, fout= 31
# i =2 , j=31, fin = 20, fout= 32
# i =2 , j=32, fin = 20, fout= 33
# i =2 , j=33, fin = 20, fout= 34
# i =2 , j=34, fin = 20, fout= 35
# i =2 , j=35, fin = 20, fout= 36
# i =2 , j=36, fin = 20, fout= 37
# i =2 , j=37, fin = 20, fout= 38
# i =2 , j=38, fin = 20, fout= 39
# i =2 , j=39, fin = 20, fout= 40
# i =2 , j=40, fin = 20, fout= 41
# i =2 , j=41, fin = 20, fout= 42
# i =2 , j=42, fin = 20, fout= 43
# i =2 , j=43, fin = 20, fout= 44
# i =2 , j=44, fin = 20, fout= 45
# i =2 , j=45, fin = 20, fout= 46
# i =2 , j=46, fin = 20, fout= 47
# i =2 , j=47, fin = 20, fout= 48
# i =2 , j=48, fin = 20, fout= 49
# i =2 , j=49, fin = 20, fout= 50
# i =2 , j=50, fin = 20, fout= 51
# i =2 , j=51, fin = 20, fout= 52
# i =2 , j=52, fin = 20, fout= 53
# i =2 , j=53, fin = 20, fout= 54
# i =2 , j=54, fin = 20, fout= 55
# i =2 , j=55, fin = 20, fout= 56
# i =2 , j=56, fin = 20, fout= 57
# i =2 , j=57, fin = 20, fout= 58
# i =2 , j=58, fin = 20, fout= 59
# i =2 , j=59, fin = 20, fout= 60
# i =2 , j=60, fin = 20, fout= 61
# i =2 , j=61, fin = 20, fout= 62
# i =2 , j=62, fin = 20, fout= 63
# i =2 , j=0, fin = 21, fout= 0
# i =2 , j=1, fin = 21, fout= 1
# i =2 , j=2, fin = 21, fout= 2
# i =2 , j=3, fin = 21, fout= 3
# i =2 , j=4, fin = 21, fout= 4
# i =2 , j=5, fin = 21, fout= 5
# i =2 , j=6, fin = 21, fout= 6
# i =2 , j=7, fin = 21, fout= 7
# i =2 , j=8, fin = 21, fout= 8
# i =2 , j=9, fin = 21, fout= 9
# i =2 , j=10, fin = 21, fout= 10
# i =2 , j=11, fin = 21, fout= 11
# i =2 , j=12, fin = 21, fout= 12
# i =2 , j=13, fin = 21, fout= 13
# i =2 , j=14, fin = 21, fout= 14
# i =2 , j=15, fin = 21, fout= 15
# i =2 , j=16, fin = 21, fout= 16
# i =2 , j=17, fin = 21, fout= 17
# i =2 , j=18, fin = 21, fout= 18
# i =2 , j=19, fin = 21, fout= 19
# i =2 , j=20, fin = 21, fout= 21
# i =2 , j=21, fin = 21, fout= 22
# i =2 , j=22, fin = 21, fout= 23
# i =2 , j=23, fin = 21, fout= 24
# i =2 , j=24, fin = 21, fout= 25
# i =2 , j=25, fin = 21, fout= 26
# i =2 , j=26, fin = 21, fout= 27
# i =2 , j=27, fin = 21, fout= 28
# i =2 , j=28, fin = 21, fout= 29
# ...
# i =2 , j=27, fin = 55, fout= 27
# i =2 , j=28, fin = 55, fout= 28
# i =2 , j=29, fin = 55, fout= 29
# i =2 , j=30, fin = 55, fout= 30
# i =2 , j=31, fin = 55, fout= 31
# i =2 , j=32, fin = 55, fout= 32
# i =2 , j=33, fin = 55, fout= 33
# i =2 , j=34, fin = 55, fout= 34
# i =2 , j=35, fin = 55, fout= 35
# i =2 , j=36, fin = 55, fout= 36
# i =2 , j=37, fin = 55, fout= 37
# i =2 , j=38, fin = 55, fout= 38
# i =2 , j=39, fin = 55, fout= 39
# i =2 , j=40, fin = 55, fout= 41
# i =2 , j=41, fin = 55, fout= 42
# i =2 , j=42, fin = 55, fout= 43
# i =2 , j=43, fin = 55, fout= 44
# i =2 , j=44, fin = 55, fout= 45
# i =2 , j=45, fin = 55, fout= 46
# i =2 , j=46, fin = 55, fout= 47
# i =2 , j=47, fin = 55, fout= 48
# i =2 , j=48, fin = 55, fout= 49
# i =2 , j=49, fin = 55, fout= 50
# i =2 , j=50, fin = 55, fout= 51
# i =2 , j=51, fin = 55, fout= 52
# i =2 , j=52, fin = 55, fout= 53
# i =2 , j=53, fin = 55, fout= 54
# i =2 , j=54, fin = 55, fout= 55
# i =2 , j=55, fin = 55, fout= 56
# i =2 , j=56, fin = 55, fout= 57
# i =2 , j=57, fin = 55, fout= 58
# i =2 , j=58, fin = 55, fout= 59
# i =2 , j=59, fin = 55, fout= 60
# i =2 , j=60, fin = 55, fout= 61
# i =2 , j=61, fin = 55, fout= 62
# i =2 , j=62, fin = 55, fout= 63
# i =2 , j=0, fin = 56, fout= 0
# i =2 , j=1, fin = 56, fout= 1
# i =2 , j=2, fin = 56, fout= 2
# i =2 , j=3, fin = 56, fout= 3
# i =2 , j=4, fin = 56, fout= 4
# i =2 , j=5, fin = 56, fout= 5
# i =2 , j=6, fin = 56, fout= 6
# i =2 , j=7, fin = 56, fout= 7
# i =2 , j=8, fin = 56, fout= 8
# i =2 , j=9, fin = 56, fout= 9
# i =2 , j=10, fin = 56, fout= 10
# i =2 , j=11, fin = 56, fout= 11
# i =2 , j=12, fin = 56, fout= 12
# i =2 , j=13, fin = 56, fout= 13
# i =2 , j=14, fin = 56, fout= 14
# i =2 , j=15, fin = 56, fout= 15
# i =2 , j=16, fin = 56, fout= 16
# i =2 , j=17, fin = 56, fout= 17
# i =2 , j=18, fin = 56, fout= 18
# i =2 , j=19, fin = 56, fout= 19
# i =2 , j=20, fin = 56, fout= 20
# i =2 , j=21, fin = 56, fout= 21
# i =2 , j=22, fin = 56, fout= 22
# i =2 , j=23, fin = 56, fout= 23
# i =2 , j=24, fin = 56, fout= 24
# i =2 , j=25, fin = 56, fout= 25
# i =2 , j=26, fin = 56, fout= 26
# i =2 , j=27, fin = 56, fout= 27
# i =2 , j=28, fin = 56, fout= 28
# i =2 , j=29, fin = 56, fout= 29
# i =2 , j=30, fin = 56, fout= 30
# i =2 , j=31, fin = 56, fout= 31
# i =2 , j=32, fin = 56, fout= 32
# i =2 , j=33, fin = 56, fout= 33
# i =2 , j=34, fin = 56, fout= 34
# i =2 , j=35, fin = 56, fout= 35
# i =2 , j=36, fin = 56, fout= 36
# i =2 , j=37, fin = 56, fout= 37
# i =2 , j=38, fin = 56, fout= 38
# i =2 , j=39, fin = 56, fout= 39
# i =2 , j=40, fin = 56, fout= 40
# i =2 , j=41, fin = 56, fout= 41
# i =2 , j=42, fin = 56, fout= 42
# i =2 , j=43, fin = 56, fout= 43
# i =2 , j=44, fin = 56, fout= 44
# i =2 , j=45, fin = 56, fout= 45
# i =2 , j=46, fin = 56, fout= 46
# i =2 , j=47, fin = 56, fout= 48
# i =2 , j=48, fin = 56, fout= 49
# i =2 , j=49, fin = 56, fout= 50
# i =2 , j=50, fin = 56, fout= 51
# i =2 , j=51, fin = 56, fout= 52
# i =2 , j=52, fin = 56, fout= 53
# i =2 , j=53, fin = 56, fout= 54
# i =2 , j=54, fin = 56, fout= 55
# i =2 , j=55, fin = 56, fout= 56
# i =2 , j=56, fin = 56, fout= 57
# i =2 , j=57, fin = 56, fout= 58
# i =2 , j=58, fin = 56, fout= 59
# i =2 , j=59, fin = 56, fout= 60
# i =2 , j=60, fin = 56, fout= 61
# i =2 , j=61, fin = 56, fout= 62
# i =2 , j=62, fin = 56, fout= 63
# i =2 , j=0, fin = 57, fout= 0
# i =2 , j=1, fin = 57, fout= 1
# i =2 , j=2, fin = 57, fout= 2
# i =2 , j=3, fin = 57, fout= 3
# i =2 , j=4, fin = 57, fout= 4
# i =2 , j=5, fin = 57, fout= 5
# i =2 , j=6, fin = 57, fout= 6
# i =2 , j=7, fin = 57, fout= 7
# i =2 , j=8, fin = 57, fout= 8
# i =2 , j=9, fin = 57, fout= 9
# i =2 , j=10, fin = 57, fout= 10
# i =2 , j=11, fin = 57, fout= 11
# i =2 , j=12, fin = 57, fout= 12
# i =2 , j=13, fin = 57, fout= 13
# i =2 , j=14, fin = 57, fout= 14
# i =2 , j=15, fin = 57, fout= 15
# i =2 , j=16, fin = 57, fout= 16
# i =2 , j=17, fin = 57, fout= 17
# i =2 , j=18, fin = 57, fout= 18
# i =2 , j=19, fin = 57, fout= 19
# i =2 , j=20, fin = 57, fout= 20
# i =2 , j=21, fin = 57, fout= 21
# i =2 , j=22, fin = 57, fout= 22
# i =2 , j=23, fin = 57, fout= 23
# i =2 , j=24, fin = 57, fout= 24
# i =2 , j=25, fin = 57, fout= 25
# i =2 , j=26, fin = 57, fout= 26
# i =2 , j=27, fin = 57, fout= 28
# i =2 , j=28, fin = 57, fout= 29
# i =2 , j=29, fin = 57, fout= 30
# i =2 , j=30, fin = 57, fout= 31
# i =2 , j=31, fin = 57, fout= 32
# i =2 , j=32, fin = 57, fout= 33
# i =2 , j=33, fin = 57, fout= 34
# i =2 , j=34, fin = 57, fout= 35
# i =2 , j=35, fin = 57, fout= 36
# i =2 , j=36, fin = 57, fout= 37
# i =2 , j=37, fin = 57, fout= 38
# i =2 , j=38, fin = 57, fout= 39
# i =2 , j=39, fin = 57, fout= 40
# i =2 , j=40, fin = 57, fout= 41
# i =2 , j=41, fin = 57, fout= 42
# i =2 , j=42, fin = 57, fout= 43
# i =2 , j=43, fin = 57, fout= 44
# i =2 , j=44, fin = 57, fout= 45
# i =2 , j=45, fin = 57, fout= 46
# i =2 , j=46, fin = 57, fout= 47
# i =2 , j=47, fin = 57, fout= 48
# i =2 , j=48, fin = 57, fout= 49
# i =2 , j=49, fin = 57, fout= 50
# i =2 , j=50, fin = 57, fout= 51
# i =2 , j=51, fin = 57, fout= 52
# i =2 , j=52, fin = 57, fout= 53
# i =2 , j=53, fin = 57, fout= 54
# i =2 , j=54, fin = 57, fout= 55
# i =2 , j=55, fin = 57, fout= 56
# i =2 , j=56, fin = 57, fout= 57
# i =2 , j=57, fin = 57, fout= 58
# i =2 , j=58, fin = 57, fout= 59
# i =2 , j=59, fin = 57, fout= 60
# i =2 , j=60, fin = 57, fout= 61
# i =2 , j=61, fin = 57, fout= 62
# i =2 , j=62, fin = 57, fout= 63
# i =2 , j=0, fin = 58, fout= 0
# i =2 , j=1, fin = 58, fout= 1
# i =2 , j=2, fin = 58, fout= 2
# i =2 , j=3, fin = 58, fout= 3
# i =2 , j=4, fin = 58, fout= 4
# i =2 , j=5, fin = 58, fout= 5
# i =2 , j=6, fin = 58, fout= 6
# i =2 , j=7, fin = 58, fout= 7
# i =2 , j=8, fin = 58, fout= 8
# i =2 , j=9, fin = 58, fout= 9
# i =2 , j=10, fin = 58, fout= 10
# i =2 , j=11, fin = 58, fout= 11
# i =2 , j=12, fin = 58, fout= 12
# i =2 , j=13, fin = 58, fout= 13
# i =2 , j=14, fin = 58, fout= 14
# i =2 , j=15, fin = 58, fout= 15
# i =2 , j=16, fin = 58, fout= 16
# i =2 , j=17, fin = 58, fout= 17
# i =2 , j=18, fin = 58, fout= 18
# i =2 , j=19, fin = 58, fout= 19
# i =2 , j=20, fin = 58, fout= 20
# i =2 , j=21, fin = 58, fout= 21
# i =2 , j=22, fin = 58, fout= 22
# i =2 , j=23, fin = 58, fout= 23
# i =2 , j=24, fin = 58, fout= 24
# i =2 , j=25, fin = 58, fout= 25
# i =2 , j=26, fin = 58, fout= 27
# i =2 , j=27, fin = 58, fout= 28
# i =2 , j=28, fin = 58, fout= 29
# i =2 , j=29, fin = 58, fout= 30
# i =2 , j=30, fin = 58, fout= 31
# i =2 , j=31, fin = 58, fout= 32
# i =2 , j=32, fin = 58, fout= 33
# i =2 , j=33, fin = 58, fout= 34
# i =2 , j=34, fin = 58, fout= 35
# i =2 , j=35, fin = 58, fout= 36
# i =2 , j=36, fin = 58, fout= 37
# i =2 , j=37, fin = 58, fout= 38
# i =2 , j=38, fin = 58, fout= 39
# i =2 , j=39, fin = 58, fout= 40
# i =2 , j=40, fin = 58, fout= 41
# i =2 , j=41, fin = 58, fout= 42
# i =2 , j=42, fin = 58, fout= 43
# i =2 , j=43, fin = 58, fout= 44
# i =2 , j=44, fin = 58, fout= 45
# i =2 , j=45, fin = 58, fout= 46
# i =2 , j=46, fin = 58, fout= 47
# i =2 , j=47, fin = 58, fout= 48
# i =2 , j=48, fin = 58, fout= 49
# i =2 , j=49, fin = 58, fout= 50
# i =2 , j=50, fin = 58, fout= 51
# i =2 , j=51, fin = 58, fout= 52
# i =2 , j=52, fin = 58, fout= 53
# i =2 , j=53, fin = 58, fout= 54
# i =2 , j=54, fin = 58, fout= 55
# i =2 , j=55, fin = 58, fout= 56
# i =2 , j=56, fin = 58, fout= 57
# i =2 , j=57, fin = 58, fout= 58
# i =2 , j=58, fin = 58, fout= 59
# i =2 , j=59, fin = 58, fout= 60
# i =2 , j=60, fin = 58, fout= 61
# i =2 , j=61, fin = 58, fout= 62
# i =2 , j=62, fin = 58, fout= 63
# i =2 , j=0, fin = 59, fout= 0
# i =2 , j=1, fin = 59, fout= 1
# i =2 , j=2, fin = 59, fout= 2
# i =2 , j=3, fin = 59, fout= 3
# i =2 , j=4, fin = 59, fout= 4
# i =2 , j=5, fin = 59, fout= 5
# i =2 , j=6, fin = 59, fout= 7
# i =2 , j=7, fin = 59, fout= 8
# i =2 , j=8, fin = 59, fout= 9
# i =2 , j=9, fin = 59, fout= 10
# i =2 , j=10, fin = 59, fout= 11
# i =2 , j=11, fin = 59, fout= 12
# i =2 , j=12, fin = 59, fout= 13
# i =2 , j=13, fin = 59, fout= 14
# i =2 , j=14, fin = 59, fout= 15
# i =2 , j=15, fin = 59, fout= 16
# i =2 , j=16, fin = 59, fout= 17
# i =2 , j=17, fin = 59, fout= 18
# i =2 , j=18, fin = 59, fout= 19
# i =2 , j=19, fin = 59, fout= 20
# i =2 , j=20, fin = 59, fout= 21
# i =2 , j=21, fin = 59, fout= 22
# i =2 , j=22, fin = 59, fout= 23
# i =2 , j=23, fin = 59, fout= 24
# i =2 , j=24, fin = 59, fout= 25
# i =2 , j=25, fin = 59, fout= 26
# i =2 , j=26, fin = 59, fout= 27
# i =2 , j=27, fin = 59, fout= 28
# i =2 , j=28, fin = 59, fout= 29
# i =2 , j=29, fin = 59, fout= 30
# i =2 , j=30, fin = 59, fout= 31
# i =2 , j=31, fin = 59, fout= 32
# i =2 , j=32, fin = 59, fout= 33
# i =2 , j=33, fin = 59, fout= 34
# i =2 , j=34, fin = 59, fout= 35
# i =2 , j=35, fin = 59, fout= 36
# i =2 , j=36, fin = 59, fout= 37
# i =2 , j=37, fin = 59, fout= 38
# i =2 , j=38, fin = 59, fout= 39
# i =2 , j=39, fin = 59, fout= 40
# i =2 , j=40, fin = 59, fout= 41
# i =2 , j=41, fin = 59, fout= 42
# i =2 , j=42, fin = 59, fout= 43
# i =2 , j=43, fin = 59, fout= 44
# i =2 , j=44, fin = 59, fout= 45
# i =2 , j=45, fin = 59, fout= 46
# i =2 , j=46, fin = 59, fout= 47
# i =2 , j=47, fin = 59, fout= 48
# i =2 , j=48, fin = 59, fout= 49
# i =2 , j=49, fin = 59, fout= 50
# i =2 , j=50, fin = 59, fout= 51
# i =2 , j=51, fin = 59, fout= 52
# i =2 , j=52, fin = 59, fout= 53
# i =2 , j=53, fin = 59, fout= 54
# i =2 , j=54, fin = 59, fout= 55
# i =2 , j=55, fin = 59, fout= 56
# i =2 , j=56, fin = 59, fout= 57
# i =2 , j=57, fin = 59, fout= 58
# i =2 , j=58, fin = 59, fout= 59
# i =2 , j=59, fin = 59, fout= 60
# i =2 , j=60, fin = 59, fout= 61
# i =2 , j=61, fin = 59, fout= 62
# i =2 , j=62, fin = 59, fout= 63
# i =2 , j=0, fin = 60, fout= 0
# i =2 , j=1, fin = 60, fout= 1
# i =2 , j=2, fin = 60, fout= 2
# i =2 , j=3, fin = 60, fout= 3
# i =2 , j=4, fin = 60, fout= 4
# i =2 , j=5, fin = 60, fout= 5
# i =2 , j=6, fin = 60, fout= 6
# i =2 , j=7, fin = 60, fout= 7
# i =2 , j=8, fin = 60, fout= 8
# i =2 , j=9, fin = 60, fout= 9
# i =2 , j=10, fin = 60, fout= 10
# i =2 , j=11, fin = 60, fout= 11
# i =2 , j=12, fin = 60, fout= 12
# i =2 , j=13, fin = 60, fout= 13
# i =2 , j=14, fin = 60, fout= 14
# i =2 , j=15, fin = 60, fout= 15
# i =2 , j=16, fin = 60, fout= 16
# i =2 , j=17, fin = 60, fout= 17
# i =2 , j=18, fin = 60, fout= 18
# i =2 , j=19, fin = 60, fout= 19
# i =2 , j=20, fin = 60, fout= 20
# i =2 , j=21, fin = 60, fout= 21
# i =2 , j=22, fin = 60, fout= 22
# i =2 , j=23, fin = 60, fout= 23
# i =2 , j=24, fin = 60, fout= 24
# i =2 , j=25, fin = 60, fout= 25
# i =2 , j=26, fin = 60, fout= 26
# i =2 , j=27, fin = 60, fout= 27
# i =2 , j=28, fin = 60, fout= 28
# i =2 , j=29, fin = 60, fout= 29
# i =2 , j=30, fin = 60, fout= 30
# i =2 , j=31, fin = 60, fout= 31
# i =2 , j=32, fin = 60, fout= 32
# i =2 , j=33, fin = 60, fout= 33
# i =2 , j=34, fin = 60, fout= 34
# i =2 , j=35, fin = 60, fout= 35
# i =2 , j=36, fin = 60, fout= 36
# i =2 , j=37, fin = 60, fout= 37
# i =2 , j=38, fin = 60, fout= 38
# i =2 , j=39, fin = 60, fout= 39
# i =2 , j=40, fin = 60, fout= 40
# i =2 , j=41, fin = 60, fout= 41
# i =2 , j=42, fin = 60, fout= 42
# i =2 , j=43, fin = 60, fout= 43
# i =2 , j=44, fin = 60, fout= 44
# i =2 , j=45, fin = 60, fout= 45
# i =2 , j=46, fin = 60, fout= 46
# i =2 , j=47, fin = 60, fout= 48
# i =2 , j=48, fin = 60, fout= 49
# i =2 , j=49, fin = 60, fout= 50
# i =2 , j=50, fin = 60, fout= 51
# i =2 , j=51, fin = 60, fout= 52
# i =2 , j=52, fin = 60, fout= 53
# i =2 , j=53, fin = 60, fout= 54
# i =2 , j=54, fin = 60, fout= 55
# i =2 , j=55, fin = 60, fout= 56
# i =2 , j=56, fin = 60, fout= 57
# i =2 , j=57, fin = 60, fout= 58
# i =2 , j=58, fin = 60, fout= 59
# i =2 , j=59, fin = 60, fout= 60
# i =2 , j=60, fin = 60, fout= 61
# i =2 , j=61, fin = 60, fout= 62
# i =2 , j=62, fin = 60, fout= 63
# i =2 , j=0, fin = 61, fout= 0
# i =2 , j=1, fin = 61, fout= 1
# i =2 , j=2, fin = 61, fout= 2
# i =2 , j=3, fin = 61, fout= 3
# i =2 , j=4, fin = 61, fout= 4
# i =2 , j=5, fin = 61, fout= 5
# i =2 , j=6, fin = 61, fout= 6
# i =2 , j=7, fin = 61, fout= 7
# i =2 , j=8, fin = 61, fout= 8
# i =2 , j=9, fin = 61, fout= 9
# i =2 , j=10, fin = 61, fout= 10
# i =2 , j=11, fin = 61, fout= 11
# i =2 , j=12, fin = 61, fout= 12
# i =2 , j=13, fin = 61, fout= 14
# i =2 , j=14, fin = 61, fout= 15
# i =2 , j=15, fin = 61, fout= 16
# i =2 , j=16, fin = 61, fout= 17
# i =2 , j=17, fin = 61, fout= 18
# i =2 , j=18, fin = 61, fout= 19
# i =2 , j=19, fin = 61, fout= 20
# i =2 , j=20, fin = 61, fout= 21
# i =2 , j=21, fin = 61, fout= 22
# i =2 , j=22, fin = 61, fout= 23
# i =2 , j=23, fin = 61, fout= 24
# i =2 , j=24, fin = 61, fout= 25
# i =2 , j=25, fin = 61, fout= 26
# i =2 , j=26, fin = 61, fout= 27
# i =2 , j=27, fin = 61, fout= 28
# i =2 , j=28, fin = 61, fout= 29
# i =2 , j=29, fin = 61, fout= 30
# i =2 , j=30, fin = 61, fout= 31
# i =2 , j=31, fin = 61, fout= 32
# i =2 , j=32, fin = 61, fout= 33
# i =2 , j=33, fin = 61, fout= 34
# i =2 , j=34, fin = 61, fout= 35
# i =2 , j=35, fin = 61, fout= 36
# i =2 , j=36, fin = 61, fout= 37
# i =2 , j=37, fin = 61, fout= 38
# i =2 , j=38, fin = 61, fout= 39
# i =2 , j=39, fin = 61, fout= 40
# i =2 , j=40, fin = 61, fout= 41
# i =2 , j=41, fin = 61, fout= 42
# i =2 , j=42, fin = 61, fout= 43
# i =2 , j=43, fin = 61, fout= 44
# i =2 , j=44, fin = 61, fout= 45
# i =2 , j=45, fin = 61, fout= 46
# i =2 , j=46, fin = 61, fout= 47
# i =2 , j=47, fin = 61, fout= 48
# i =2 , j=48, fin = 61, fout= 49
# i =2 , j=49, fin = 61, fout= 50
# i =2 , j=50, fin = 61, fout= 51
# i =2 , j=51, fin = 61, fout= 52
# i =2 , j=52, fin = 61, fout= 53
# i =2 , j=53, fin = 61, fout= 54
# i =2 , j=54, fin = 61, fout= 55
# i =2 , j=55, fin = 61, fout= 56
# i =2 , j=56, fin = 61, fout= 57
# i =2 , j=57, fin = 61, fout= 58
# i =2 , j=58, fin = 61, fout= 59
# i =2 , j=59, fin = 61, fout= 60
# i =2 , j=60, fin = 61, fout= 61
# i =2 , j=61, fin = 61, fout= 62
# i =2 , j=62, fin = 61, fout= 63
# i =2 , j=0, fin = 62, fout= 0
# i =2 , j=1, fin = 62, fout= 1
# i =2 , j=2, fin = 62, fout= 2
# i =2 , j=3, fin = 62, fout= 3
# i =2 , j=4, fin = 62, fout= 4
# i =2 , j=5, fin = 62, fout= 5
# i =2 , j=6, fin = 62, fout= 6
# i =2 , j=7, fin = 62, fout= 7
# i =2 , j=8, fin = 62, fout= 8
# i =2 , j=9, fin = 62, fout= 9
# i =2 , j=10, fin = 62, fout= 10
# i =2 , j=11, fin = 62, fout= 11
# i =2 , j=12, fin = 62, fout= 12
# i =2 , j=13, fin = 62, fout= 13
# i =2 , j=14, fin = 62, fout= 14
# i =2 , j=15, fin = 62, fout= 15
# i =2 , j=16, fin = 62, fout= 16
# i =2 , j=17, fin = 62, fout= 17
# i =2 , j=18, fin = 62, fout= 18
# i =2 , j=19, fin = 62, fout= 19
# i =2 , j=20, fin = 62, fout= 20
# i =2 , j=21, fin = 62, fout= 21
# i =2 , j=22, fin = 62, fout= 22
# i =2 , j=23, fin = 62, fout= 23
# i =2 , j=24, fin = 62, fout= 24
# i =2 , j=25, fin = 62, fout= 25
# i =2 , j=26, fin = 62, fout= 26
# i =2 , j=27, fin = 62, fout= 27
# i =2 , j=28, fin = 62, fout= 28
# i =2 , j=29, fin = 62, fout= 29
# i =2 , j=30, fin = 62, fout= 30
# i =2 , j=31, fin = 62, fout= 31
# i =2 , j=32, fin = 62, fout= 32
# i =2 , j=33, fin = 62, fout= 33
# i =2 , j=34, fin = 62, fout= 34
# i =2 , j=35, fin = 62, fout= 35
# i =2 , j=36, fin = 62, fout= 36
# i =2 , j=37, fin = 62, fout= 37
# i =2 , j=38, fin = 62, fout= 38
# i =2 , j=39, fin = 62, fout= 40
# i =2 , j=40, fin = 62, fout= 41
# i =2 , j=41, fin = 62, fout= 42
# i =2 , j=42, fin = 62, fout= 43
# i =2 , j=43, fin = 62, fout= 44
# i =2 , j=44, fin = 62, fout= 45
# i =2 , j=45, fin = 62, fout= 46
# i =2 , j=46, fin = 62, fout= 47
# i =2 , j=47, fin = 62, fout= 48
# i =2 , j=48, fin = 62, fout= 49
# i =2 , j=49, fin = 62, fout= 50
# i =2 , j=50, fin = 62, fout= 51
# i =2 , j=51, fin = 62, fout= 52
# i =2 , j=52, fin = 62, fout= 53
# i =2 , j=53, fin = 62, fout= 54
# i =2 , j=54, fin = 62, fout= 55
# i =2 , j=55, fin = 62, fout= 56
# i =2 , j=56, fin = 62, fout= 57
# i =2 , j=57, fin = 62, fout= 58
# i =2 , j=58, fin = 62, fout= 59
# i =2 , j=59, fin = 62, fout= 60
# i =2 , j=60, fin = 62, fout= 61
# i =2 , j=61, fin = 62, fout= 62
# i =2 , j=62, fin = 62, fout= 63
# i =2 , j=0, fin = 63, fout= 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_111478/3576888522.py in <module>
#      14                         j = j+1
#      15             count = count +1
# ---> 16 deepCopy(destModel=tempModel,sourceModel=newModel,featureList=featureList)
#
# /tmp/ipykernel_111478/3576888522.py in deepCopy(destModel, sourceModel, featureList)
#      11                         if j>=featureList[count]:
#      12                             break
# ---> 13                         destModel.features[i]._parameters['weight'][j][fin]=sourceModel.features[i]._parameters['weight'][fout][fin]
#      14                         j = j+1
#      15             count = count +1
#
# IndexError: index 63 is out of bounds for dimension 0 with size 63

# %%
size = tempModel.features[0]._parameters['weight'].shape
for i in range(size[0]):    
    for j in range(size[1]):
        print(tempModel.features[0]._parameters['weight'][i][j])
# Out:
# tensor([[-0.0086, -0.0151, -0.0473],
#         [ 0.0867,  0.0719,  0.0495],
#         [-0.0741, -0.0980, -0.1383]])
# tensor([[-0.0062,  0.1087, -0.0627],
#         [-0.0650, -0.0768,  0.0404],
#         [ 0.0644, -0.0034, -0.0673]])
# tensor([[ 0.0046,  0.0079, -0.0865],
#         [ 0.0451, -0.0264,  0.0073],
#         [ 0.0166,  0.0621,  0.0355]])
# tensor([[ 0.0129, -0.0671, -0.0872],
#         [-0.0564, -0.0776, -0.0511],
#         [-0.0651,  0.0022, -0.0751]])
# tensor([[-0.0901,  0.0443,  0.0280],
#         [ 0.0566,  0.0039,  0.0122],
#         [-0.0718, -0.0013, -0.1013]])
# tensor([[-0.0316,  0.0388,  0.0079],
#         [-0.0181, -0.0600,  0.0848],
#         [ 0.0114,  0.0648, -0.0571]])
# tensor([[-0.1250,  0.0158,  0.0117],
#         [-0.0562,  0.0576, -0.0260],
#         [-0.0155, -0.0512, -0.0119]])
# tensor([[-0.0395,  0.0532, -0.1267],
#         [-0.0152,  0.0210, -0.0008],
#         [-0.0412,  0.0833,  0.0394]])
# tensor([[-0.0640,  0.1208,  0.0524],
#         [ 0.0603,  0.0362, -0.0901],
#         [ 0.0548, -0.0060,  0.1130]])
# tensor([[-0.0231,  0.0382,  0.0423],
#         [-0.0697, -0.0310,  0.0609],
#         [-0.0314,  0.1416,  0.0388]])
# tensor([[-0.0379,  0.0313, -0.0509],
#         [ 0.0516, -0.0813,  0.0179],
#         [-0.0031, -0.0159, -0.0075]])
# tensor([[-0.0361, -0.0021,  0.0371],
#         [ 0.0080, -0.0849,  0.0316],
#         [-0.0389,  0.0629, -0.0124]])
# tensor([[-0.0223,  0.1164, -0.1032],
#         [-0.0595,  0.1105, -0.0490],
#         [-0.0373, -0.0403, -0.0589]])
# tensor([[ 0.0371, -0.0032, -0.0613],
#         [-0.1373,  0.0744,  0.0570],
#         [-0.0206,  0.0135,  0.0488]])
# tensor([[ 0.0239, -0.0604,  0.0130],
#         [ 0.0633,  0.0313, -0.0569],
#         [ 0.0178, -0.0127, -0.0841]])
# tensor([[ 1.0800e-01,  5.7297e-05,  8.3585e-02],
#         [-5.1838e-02, -1.5284e-02, -3.4450e-02],
#         [ 3.5191e-02,  1.0424e-01, -6.2037e-05]])
# tensor([[-0.0125,  0.0381, -0.0066],
#         [-0.0273, -0.0464,  0.0502],
#         [ 0.2044,  0.0611,  0.0019]])
# tensor([[-0.0079,  0.0511,  0.0345],
#         [-0.0189, -0.0156,  0.0019],
#         [-0.0279,  0.0176, -0.0119]])
# tensor([[-0.0449,  0.0900,  0.0160],
#         [-0.0659, -0.0847, -0.0417],
#         [-0.0140, -0.1629,  0.0186]])
# tensor([[-0.0253,  0.0432,  0.0597],
#         [ 0.0105,  0.0353, -0.0170],
#         [-0.0103,  0.0247,  0.0717]])
# tensor([[-0.0050, -0.0099, -0.0473],
#         [-0.0304,  0.0123,  0.1137],
#         [-0.0099, -0.0234,  0.0443]])
# tensor([[-0.1404,  0.0403,  0.1126],
#         [-0.0430,  0.1479,  0.0211],
#         [-0.0243, -0.0718,  0.0394]])
# tensor([[-0.0919, -0.0072,  0.0069],
#         [-0.0523, -0.0705,  0.0289],
#         [ 0.0160,  0.0418,  0.1094]])
# tensor([[-0.0010, -0.0127,  0.0890],
#         [ 0.0405,  0.0276, -0.0798],
#         [ 0.0024, -0.0119,  0.0606]])
# tensor([[-0.0161,  0.0633, -0.0502],
#         [-0.0845, -0.0683,  0.0221],
#         [ 0.0773,  0.0330, -0.0146]])
# tensor([[ 0.0161, -0.0851, -0.0496],
#         [-0.0681,  0.1144, -0.0112],
#         [ 0.0054, -0.0588,  0.0292]])
# tensor([[ 0.0677, -0.0595, -0.0259],
#         [-0.1320,  0.0783, -0.0024],
#         [ 0.0315, -0.0605, -0.0373]])
# tensor([[-0.0194,  0.0155, -0.0399],
#         [ 0.0986, -0.0819, -0.0869],
#         [-0.0805, -0.0629,  0.0765]])
# tensor([[ 0.0533,  0.0464,  0.0802],
#         [-0.0488,  0.0461, -0.0537],
#         [-0.0694,  0.0075, -0.0419]])
# tensor([[ 0.0075, -0.0816, -0.1456],
#         [-0.0903, -0.0654, -0.1131],
#         [ 0.0142, -0.0957,  0.0161]])
# tensor([[ 0.1255,  0.0287, -0.0187],
#         [-0.0021, -0.0171, -0.1195],
#         [ 0.0213, -0.0254, -0.0009]])
# tensor([[-0.0050, -0.0195, -0.0034],
#         [-0.0469,  0.0583,  0.0695],
#         [ 0.0390, -0.0174, -0.0365]])
# tensor([[-0.0140, -0.0893,  0.0108],
#         [ 0.0009, -0.0298, -0.0684],
#         [-0.0928,  0.0860, -0.0514]])
# tensor([[-0.0247,  0.0460, -0.0015],
#         [-0.0108,  0.0464,  0.0600],
#         [ 0.0857,  0.0474, -0.0238]])
# tensor([[ 6.8060e-02, -4.2283e-03, -3.1933e-02],
#         [-7.9418e-02, -9.1390e-02,  9.5601e-05],
#         [-3.6389e-02, -1.8479e-03, -2.3800e-04]])
# tensor([[-0.0411,  0.0788, -0.0386],
#         [ 0.0221,  0.0577,  0.0328],
#         [ 0.0618, -0.0562,  0.0609]])
# tensor([[ 0.0455, -0.0836,  0.0430],
#         [-0.0112,  0.0750,  0.0556],
#         [ 0.0009, -0.0274, -0.0134]])
# tensor([[-0.0817,  0.0448,  0.0634],
#         [ 0.1068,  0.0328, -0.0296],
#         [-0.0257, -0.0864,  0.0638]])
# tensor([[ 0.0308, -0.0651,  0.0053],
#         [ 0.0148, -0.0935,  0.0170],
#         [-0.0245,  0.1038,  0.0077]])
# tensor([[-0.0847,  0.0177,  0.0127],
#         [-0.0168,  0.0008, -0.0368],
#         [-0.0855,  0.0527, -0.0425]])
# tensor([[ 0.0674, -0.0301,  0.0414],
#         [ 0.0641,  0.0147, -0.0961],
#         [-0.0377,  0.0708, -0.0109]])
# tensor([[ 0.0009,  0.1056,  0.0541],
#         [ 0.0272, -0.0197, -0.0317],
#         [-0.0571, -0.0265, -0.0228]])
# tensor([[-0.0537,  0.1068,  0.0190],
#         [-0.0783, -0.0848, -0.0402],
#         [ 0.0538,  0.0900, -0.0316]])
# tensor([[ 0.0285,  0.0916,  0.0083],
#         [-0.1034,  0.0357,  0.0217],
#         [-0.0058, -0.0405, -0.1429]])
# tensor([[-0.0755, -0.0413, -0.0684],
#         [ 0.0071,  0.0144,  0.0236],
#         [-0.0116, -0.0100, -0.0544]])
# tensor([[-0.0252, -0.0249,  0.0293],
#         [-0.0110, -0.0694,  0.0398],
#         [-0.0309, -0.0236, -0.0810]])
# tensor([[-0.0602,  0.0376,  0.0254],
#         [ 0.0840, -0.0444,  0.0483],
#         [ 0.0160, -0.0489, -0.0326]])
# tensor([[-0.0094,  0.0481,  0.0364],
#         [ 0.0133, -0.0157, -0.0286],
#         [-0.1062, -0.0327,  0.0488]])
# tensor([[-0.0127,  0.1218,  0.0082],
#         [ 0.0029, -0.0008,  0.0444],
#         [ 0.1076, -0.0269,  0.0470]])
# tensor([[ 0.0890,  0.0489,  0.0028],
#         [-0.0011, -0.0956, -0.0539],
#         [ 0.0715,  0.0104, -0.1057]])
# tensor([[-0.0966, -0.0265, -0.0441],
#         [ 0.0112,  0.0388, -0.1017],
#         [ 0.0660, -0.0553, -0.0002]])
# tensor([[ 0.0299, -0.0458,  0.0127],
#         [-0.0057,  0.0367,  0.0068],
#         [-0.0691, -0.0113, -0.0363]])
# tensor([[-0.0786,  0.0886,  0.0420],
#         [-0.0066, -0.1359, -0.0386],
#         [-0.0883, -0.0797, -0.0468]])
# tensor([[ 0.0242,  0.0838,  0.0317],
#         [ 0.0118,  0.0403,  0.0729],
#         [ 0.0289, -0.0794,  0.0029]])
# tensor([[ 0.1503,  0.1181,  0.0232],
#         [-0.0237,  0.0350,  0.0037],
#         [-0.0065, -0.0854,  0.0726]])
# tensor([[ 0.0229,  0.0558, -0.0022],
#         [ 0.0221,  0.0406, -0.0842],
#         [-0.0411, -0.0320,  0.0398]])
# tensor([[-0.0514,  0.0851,  0.0338],
#         [-0.1382, -0.0911, -0.0188],
#         [ 0.0725,  0.0449,  0.0004]])
# tensor([[ 0.1166, -0.1297, -0.0203],
#         [ 0.0323,  0.0379,  0.0888],
#         [ 0.1304,  0.0413,  0.0249]])
# tensor([[-0.0658,  0.0196, -0.0533],
#         [ 0.0709, -0.0337, -0.0479],
#         [-0.0155,  0.0357,  0.0625]])
# tensor([[-0.0508,  0.0009,  0.0094],
#         [-0.0800, -0.0281, -0.0225],
#         [-0.0326, -0.0962, -0.0298]])
# tensor([[ 0.0133, -0.0813, -0.0358],
#         [ 0.0867, -0.0102,  0.0333],
#         [-0.0283,  0.0235,  0.0173]])
# tensor([[-0.0400, -0.0285, -0.0363],
#         [-0.0607,  0.0400, -0.0455],
#         [-0.0653,  0.0392,  0.0228]])
# tensor([[-0.0334, -0.1240, -0.0564],
#         [ 0.0927, -0.0947, -0.0375],
#         [ 0.0196, -0.0682, -0.0391]])
# tensor([[ 0.0188,  0.1075, -0.0794],
#         [ 0.0960,  0.1246,  0.1014],
#         [-0.0525, -0.0201,  0.0273]])
# tensor([[-0.0127, -0.0055, -0.0650],
#         [-0.0191, -0.0563, -0.0017],
#         [ 0.0179, -0.0239,  0.0575]])
# tensor([[-0.0431,  0.0680,  0.0798],
#         [-0.0842,  0.0171, -0.0571],
#         [-0.0063,  0.1035,  0.0652]])
# tensor([[-0.0394, -0.0204, -0.0732],
#         [ 0.0443,  0.0757,  0.0553],
#         [-0.0253,  0.0165, -0.0951]])
# tensor([[ 0.0272, -0.0536,  0.1496],
#         [-0.0772,  0.0065,  0.0083],
#         [ 0.0780, -0.1108, -0.0504]])
# tensor([[-0.0033,  0.0462, -0.0554],
#         [-0.0545,  0.0216,  0.1141],
#         [-0.0154,  0.0880, -0.0506]])
# tensor([[-0.0251, -0.0607,  0.0108],
#         [-0.0094,  0.0782,  0.0192],
#         [-0.0252, -0.0047,  0.0863]])
# tensor([[-0.0810,  0.0369,  0.0811],
#         [ 0.0495,  0.0153, -0.0392],
#         [-0.0214, -0.0164, -0.0232]])
# tensor([[ 0.0536,  0.0242,  0.0086],
#         [ 0.0192, -0.0275, -0.0278],
#         [-0.0133,  0.1554, -0.0492]])
# tensor([[ 0.0389, -0.0281,  0.0128],
#         [ 0.0741,  0.0078, -0.0293],
#         [-0.0308, -0.0053,  0.0726]])
# tensor([[-0.0712,  0.1106,  0.0637],
#         [ 0.0882,  0.0076,  0.0120],
#         [-0.0382, -0.0753, -0.0934]])
# tensor([[-0.0313, -0.0018,  0.0839],
#         [ 0.0465,  0.0611,  0.0484],
#         [ 0.0381,  0.0890,  0.0196]])
# tensor([[-0.0576,  0.0431,  0.0565],
#         [ 0.1167,  0.0222, -0.1608],
#         [-0.0336, -0.0218, -0.0982]])
# tensor([[-0.0396,  0.0730, -0.0616],
#         [ 0.0524,  0.0351, -0.0020],
#         [-0.0278, -0.0760, -0.0382]])
# tensor([[ 0.0331, -0.0214, -0.0200],
#         [-0.0072,  0.0514,  0.0801],
#         [-0.0551, -0.0036, -0.0111]])
# tensor([[ 0.0211,  0.0385,  0.0185],
#         [-0.0787, -0.0170, -0.0205],
#         [-0.0035,  0.0105,  0.0716]])
# tensor([[-0.0487, -0.1310, -0.0022],
#         [-0.0190, -0.0380,  0.0060],
#         [-0.0282, -0.0717,  0.0674]])
# tensor([[-0.0379, -0.0560,  0.0950],
#         [-0.0411, -0.0210, -0.0122],
#         [-0.0378, -0.0391, -0.0680]])
# tensor([[ 0.0677,  0.0169,  0.0353],
#         [-0.0473, -0.1089, -0.0289],
#         [-0.0026, -0.0530,  0.0087]])
# tensor([[ 0.0064, -0.0022, -0.0230],
#         [-0.0344, -0.0374, -0.0186],
#         [-0.0301,  0.0447, -0.0519]])
# tensor([[-0.0466,  0.0075,  0.0148],
#         [ 0.0793,  0.0692, -0.0093],
#         [-0.0915, -0.1007,  0.0610]])
# tensor([[-0.0679,  0.0124,  0.0459],
#         [ 0.0516,  0.0899, -0.0542],
#         [-0.0406,  0.0957,  0.0484]])
# tensor([[-0.0209, -0.0544,  0.0391],
#         [-0.0344, -0.1357,  0.0006],
#         [-0.0831, -0.0012, -0.0015]])
# tensor([[ 0.0501,  0.0699,  0.0276],
#         [ 0.0491,  0.0054, -0.0651],
#         [-0.0691, -0.0537,  0.0377]])
# tensor([[ 0.0682,  0.0140,  0.0028],
#         [ 0.0164,  0.0296,  0.0233],
#         [-0.0018, -0.0064,  0.0104]])
# tensor([[ 0.0180,  0.0657,  0.0500],
#         [ 0.0196,  0.0165,  0.0200],
#         [ 0.0925, -0.0006,  0.0569]])
# tensor([[-0.0591, -0.0327, -0.0781],
#         [-0.0773, -0.0528,  0.0159],
#         [ 0.1072, -0.0137,  0.0315]])
# tensor([[-0.0307,  0.0720, -0.0544],
#         [-0.0374,  0.0769,  0.0459],
#         [ 0.0472,  0.0155,  0.0499]])
# tensor([[-0.0306,  0.0337, -0.0338],
#         [ 0.1199, -0.0112, -0.0691],
#         [ 0.0313,  0.1236, -0.0045]])
# tensor([[-0.0404, -0.0836,  0.0926],
#         [ 0.0886,  0.0391, -0.0482],
#         [-0.0877, -0.0558, -0.0340]])
# tensor([[-0.0270,  0.0410, -0.0718],
#         [-0.0442, -0.0725, -0.0640],
#         [-0.0327, -0.0050,  0.0246]])
# tensor([[-0.0328,  0.0503,  0.0182],
#         [-0.0574, -0.0409, -0.0451],
#         [ 0.0652,  0.0866,  0.0016]])
# tensor([[ 0.0748, -0.1209, -0.1152],
#         [-0.1020,  0.0187,  0.0247],
#         [ 0.0177, -0.0262, -0.0446]])
# tensor([[-0.0191,  0.0755, -0.1286],
#         [-0.0147, -0.0451,  0.0174],
#         [ 0.0660, -0.0453,  0.1037]])
# tensor([[-0.0719, -0.0432,  0.0647],
#         [ 0.0251,  0.0237,  0.0516],
#         [-0.0253,  0.1073, -0.0294]])
# tensor([[ 0.0861,  0.0777, -0.0540],
#         [ 0.0313,  0.0082,  0.0271],
#         [ 0.0150, -0.0464,  0.0795]])
# tensor([[-0.0844, -0.0412, -0.0746],
#         [-0.0654, -0.0148,  0.0009],
#         [ 0.1059, -0.0216,  0.0059]])
# tensor([[-0.0035, -0.0407, -0.0234],
#         [-0.0198, -0.0444,  0.0485],
#         [-0.0398, -0.0024, -0.0174]])
# tensor([[ 0.0327, -0.0088, -0.0088],
#         [ 0.0245, -0.0743,  0.0225],
#         [ 0.0150,  0.0197,  0.0216]])
# tensor([[-0.0105,  0.0282, -0.0235],
#         [ 0.0840,  0.0117, -0.0144],
#         [-0.0700, -0.0090, -0.0267]])
# tensor([[-0.0782,  0.0918,  0.1072],
#         [-0.0194, -0.0351,  0.1043],
#         [ 0.0572, -0.0636,  0.0099]])
# tensor([[ 0.0920, -0.0264, -0.1131],
#         [ 0.0554, -0.0231, -0.0886],
#         [-0.0095,  0.0090, -0.0198]])
# tensor([[-0.1039,  0.0082, -0.0549],
#         [-0.0158, -0.0661, -0.0795],
#         [-0.1325, -0.0216, -0.1039]])
# tensor([[ 0.0297, -0.0614, -0.1203],
#         [-0.0621, -0.0006,  0.0611],
#         [-0.0749,  0.1329, -0.0634]])
# tensor([[ 0.0081, -0.0719, -0.0758],
#         [ 0.0140,  0.0181,  0.0176],
#         [ 0.0708, -0.0425, -0.0166]])
# tensor([[ 0.0510, -0.0427, -0.0468],
#         [ 0.0421, -0.0099,  0.0830],
#         [-0.0244, -0.0683, -0.0812]])
# tensor([[ 0.0063,  0.0542, -0.0378],
#         [ 0.0032,  0.1660,  0.0074],
#         [-0.0823,  0.0093, -0.0362]])
# tensor([[-0.0362,  0.1293, -0.0021],
#         [-0.0028, -0.0644,  0.0034],
#         [-0.0205,  0.1020, -0.0053]])
# tensor([[ 0.0446,  0.0475, -0.0548],
#         [-0.0392,  0.0285, -0.0292],
#         [-0.0459, -0.0187, -0.0682]])
# tensor([[ 0.0215,  0.0288,  0.0810],
#         [-0.0828,  0.1114,  0.0186],
#         [-0.0358, -0.0381, -0.1009]])
# tensor([[ 0.0207,  0.0237, -0.0781],
#         [-0.0084,  0.0068,  0.0404],
#         [-0.0076, -0.0474,  0.0309]])
# tensor([[ 0.0480, -0.0955, -0.0036],
#         [-0.0231, -0.0439,  0.0428],
#         [-0.0069,  0.0570,  0.0414]])
# tensor([[-0.0013,  0.0622,  0.0006],
#         [-0.0567,  0.0980,  0.0385],
#         [-0.0552,  0.0018, -0.0423]])
# tensor([[-0.0891, -0.0256,  0.0389],
#         [-0.0377,  0.0385,  0.0793],
#         [ 0.0254, -0.0338,  0.0247]])
# tensor([[-0.0644, -0.2357, -0.0630],
#         [-0.0536, -0.0298, -0.0388],
#         [-0.0886,  0.0424,  0.1231]])
# tensor([[ 0.0784, -0.1144,  0.0565],
#         [-0.0053, -0.0694,  0.0952],
#         [ 0.0533,  0.0165, -0.0730]])
# tensor([[ 0.0254,  0.0867,  0.0483],
#         [-0.0267,  0.0805,  0.0562],
#         [-0.0215,  0.0594,  0.0246]])
# tensor([[ 0.0441,  0.1327, -0.0284],
#         [-0.0131, -0.0392, -0.0021],
#         [ 0.0772,  0.0126, -0.0359]])
# tensor([[-0.0569,  0.0169, -0.0613],
#         [ 0.1102,  0.0175, -0.0310],
#         [ 0.0047, -0.0593, -0.0743]])
# tensor([[ 0.0680,  0.0142, -0.0045],
#         [ 0.0382,  0.0002,  0.1029],
#         [ 0.0486, -0.0441, -0.0158]])
# tensor([[-0.0687, -0.0012,  0.0608],
#         [ 0.0719,  0.0227,  0.0764],
#         [-0.0170,  0.0991,  0.0129]])
# tensor([[ 0.0099, -0.0616,  0.0189],
#         [-0.0716, -0.0649, -0.0218],
#         [ 0.0350, -0.0859,  0.0293]])
# tensor([[-0.0891,  0.0795, -0.0061],
#         [-0.0257, -0.0642,  0.0217],
#         [ 0.0047, -0.0440, -0.0182]])
# tensor([[-0.0195, -0.0081, -0.1422],
#         [ 0.0214,  0.0975,  0.0429],
#         [-0.0074, -0.0227,  0.0319]])
# tensor([[ 0.0758,  0.0066,  0.0956],
#         [ 0.0238, -0.0116,  0.0199],
#         [-0.0566, -0.0320,  0.0511]])
# tensor([[-0.0143, -0.0318,  0.1295],
#         [ 0.0819,  0.0346,  0.0355],
#         [-0.0241, -0.1175, -0.0919]])
# tensor([[ 0.0758,  0.1102, -0.0006],
#         [-0.0057, -0.0147,  0.0489],
#         [-0.0017,  0.0502,  0.0320]])
# tensor([[-0.0440, -0.0263, -0.0393],
#         [ 0.0438, -0.0123, -0.0388],
#         [ 0.1675, -0.0321,  0.0470]])
# tensor([[-0.0292,  0.0336,  0.0329],
#         [ 0.0299,  0.0214,  0.0565],
#         [ 0.1713, -0.0241, -0.0324]])
# tensor([[-0.0581,  0.0290,  0.0094],
#         [ 0.0470,  0.0623, -0.0860],
#         [ 0.0475,  0.0043,  0.0256]])
# tensor([[-0.0901, -0.0574, -0.1250],
#         [ 0.0546, -0.1215,  0.0326],
#         [-0.0094, -0.0763,  0.0653]])
# tensor([[ 0.0025, -0.0333,  0.0351],
#         [-0.0236,  0.0259,  0.0523],
#         [ 0.0687,  0.0159, -0.0419]])
# tensor([[ 0.0561, -0.0169, -0.1305],
#         [-0.0692,  0.0036, -0.0144],
#         [ 0.0627,  0.0069,  0.0168]])
# tensor([[ 0.0731,  0.0194,  0.0484],
#         [ 0.0286, -0.0638, -0.0447],
#         [-0.0135,  0.0013,  0.0647]])
# tensor([[ 0.0531,  0.0428,  0.0367],
#         [-0.0307, -0.0809,  0.0709],
#         [-0.0110,  0.0746,  0.0257]])
# tensor([[-0.0070, -0.0339, -0.0347],
#         [ 0.0941, -0.0186,  0.0509],
#         [-0.0280,  0.0647, -0.0325]])
# tensor([[ 0.0083, -0.0107,  0.0509],
#         [ 0.0222,  0.0390,  0.0344],
#         [ 0.0087, -0.0811,  0.0392]])
# tensor([[ 0.0843,  0.0377, -0.0875],
#         [ 0.0236, -0.0502,  0.0609],
#         [ 0.0206, -0.1077, -0.0719]])
# tensor([[ 0.0027,  0.0210,  0.0351],
#         [-0.0866, -0.0663, -0.0039],
#         [ 0.0043,  0.0249, -0.0736]])
# tensor([[-0.0669, -0.0370,  0.0845],
#         [-0.0455,  0.0202, -0.0363],
#         [ 0.0210, -0.0498, -0.0763]])
# tensor([[-0.0357,  0.0365,  0.0695],
#         [ 0.0865,  0.0833, -0.0430],
#         [-0.0384,  0.0144,  0.0885]])
# tensor([[-0.1068, -0.0439, -0.0458],
#         [-0.0380, -0.0264, -0.0135],
#         [ 0.0603, -0.0831, -0.0050]])
# tensor([[ 0.0225, -0.0102, -0.1269],
#         [-0.0871, -0.0061,  0.1070],
#         [ 0.0381, -0.0264, -0.0283]])
# tensor([[ 0.1441, -0.0552,  0.0369],
#         [-0.0590, -0.0660,  0.0198],
#         [ 0.0220,  0.0905, -0.0781]])
# tensor([[ 0.0425, -0.0264, -0.0246],
#         [ 0.0122,  0.0225,  0.0547],
#         [ 0.0547,  0.0693, -0.0217]])
# tensor([[-0.0249,  0.0231, -0.0186],
#         [-0.0592, -0.0450, -0.0752],
#         [-0.0851, -0.0441, -0.0940]])
# tensor([[ 0.0615,  0.0295, -0.0824],
#         [ 0.0552,  0.0597, -0.0475],
#         [ 0.0530, -0.0473,  0.0613]])
# tensor([[ 0.0210, -0.0475,  0.0551],
#         [-0.0155,  0.1198, -0.0686],
#         [-0.0362, -0.0016,  0.0730]])
# tensor([[-0.0304, -0.1329, -0.0206],
#         [-0.1505,  0.0563, -0.0247],
#         [ 0.0285,  0.0428,  0.0510]])
# tensor([[-0.0480,  0.0834,  0.0235],
#         [ 0.0130, -0.0180,  0.0016],
#         [ 0.0021,  0.0255, -0.0158]])
# tensor([[-0.0675,  0.0443,  0.0022],
#         [ 0.0566, -0.0723,  0.0041],
#         [ 0.0833, -0.0267, -0.0056]])
# tensor([[ 0.0488, -0.1105, -0.0238],
#         [-0.0725, -0.0565,  0.0529],
#         [ 0.0213,  0.0048,  0.0659]])
# tensor([[-0.0702,  0.0241, -0.0257],
#         [ 0.0641, -0.0475,  0.0336],
#         [-0.0439,  0.0758, -0.1071]])
# tensor([[-0.0363,  0.0577,  0.0131],
#         [ 0.1046, -0.1073, -0.0436],
#         [-0.0237,  0.0826,  0.1314]])
# tensor([[-0.0801, -0.1364, -0.0181],
#         [-0.0616, -0.0700, -0.0819],
#         [ 0.0368, -0.0335, -0.0681]])
# tensor([[ 0.0532, -0.0504, -0.0454],
#         [ 0.0243,  0.0567, -0.0199],
#         [-0.0857, -0.1474, -0.1115]])
# tensor([[ 0.0422,  0.0298, -0.0514],
#         [ 0.0891,  0.1034, -0.0795],
#         [-0.1091, -0.0307, -0.0834]])
# tensor([[-0.1224,  0.0266, -0.0770],
#         [-0.0352, -0.0791,  0.0370],
#         [-0.1296,  0.0434, -0.0636]])
# tensor([[ 0.0631,  0.0624, -0.1042],
#         [-0.0655,  0.0429,  0.1018],
#         [-0.1084,  0.0980,  0.0229]])
# tensor([[ 0.0422,  0.0686, -0.0045],
#         [-0.1534, -0.0845,  0.0035],
#         [ 0.0504,  0.0083, -0.1068]])
# tensor([[ 0.0770, -0.0105, -0.0634],
#         [ 0.0132,  0.0155,  0.0442],
#         [ 0.0219, -0.0247,  0.0859]])
# tensor([[ 0.0124, -0.0045,  0.0355],
#         [-0.0217, -0.0882, -0.0430],
#         [ 0.1024, -0.0145,  0.0170]])
# tensor([[ 0.1013, -0.0699, -0.0851],
#         [-0.1515,  0.0267, -0.0692],
#         [ 0.0289, -0.0803,  0.0738]])
# tensor([[ 0.0817, -0.0447,  0.0867],
#         [ 0.0169,  0.0940, -0.0890],
#         [-0.0143, -0.0009, -0.0017]])
# tensor([[-0.0159,  0.0260,  0.0087],
#         [-0.0730,  0.0592,  0.0753],
#         [-0.0758,  0.0078,  0.0038]])
# tensor([[-0.0731, -0.0119,  0.0629],
#         [ 0.0368,  0.0975,  0.0906],
#         [ 0.0346, -0.0783,  0.0623]])
# tensor([[ 0.0938, -0.0910,  0.0118],
#         [ 0.1778, -0.0258,  0.1115],
#         [ 0.0031, -0.0216, -0.0220]])
# tensor([[ 0.0357, -0.0053, -0.0210],
#         [-0.0129,  0.0355,  0.0428],
#         [ 0.0152, -0.0046, -0.0308]])
# tensor([[-0.0689,  0.0428,  0.0603],
#         [-0.0098, -0.0517,  0.1218],
#         [ 0.0252, -0.0089, -0.0052]])
# tensor([[ 0.0090,  0.0995, -0.0015],
#         [-0.1008,  0.0021,  0.0781],
#         [-0.0588, -0.0296, -0.0603]])
# tensor([[-0.0403,  0.0442,  0.1118],
#         [ 0.0476, -0.0414,  0.0322],
#         [ 0.0598,  0.0619,  0.0310]])
# tensor([[ 0.0489, -0.0515, -0.0944],
#         [-0.0091, -0.0431, -0.0029],
#         [-0.0714,  0.0116,  0.0695]])
# tensor([[-0.0766,  0.0204, -0.0036],
#         [-0.0809, -0.0242, -0.0044],
#         [ 0.0636, -0.0264, -0.0491]])
# tensor([[-0.1324, -0.1273, -0.1048],
#         [ 0.1420,  0.0411,  0.0005],
#         [ 0.0382,  0.0257,  0.0431]])
# tensor([[-0.0327, -0.0313, -0.0267],
#         [ 0.0125,  0.0320,  0.0231],
#         [ 0.0088,  0.0630, -0.0977]])
# tensor([[-0.0174, -0.0963,  0.0586],
#         [ 0.0292, -0.0251,  0.0085],
#         [-0.0726,  0.0472,  0.0964]])
# tensor([[-0.0978,  0.0942,  0.0210],
#         [-0.0002,  0.0457, -0.0393],
#         [-0.0203,  0.0047, -0.0643]])
# tensor([[-0.0363,  0.0177, -0.0234],
#         [ 0.0168, -0.0307, -0.0900],
#         [ 0.0138,  0.0276,  0.0100]])
# tensor([[ 0.0164, -0.0349,  0.0985],
#         [ 0.0941,  0.0315, -0.0011],
#         [ 0.0334,  0.0345, -0.0021]])
# tensor([[ 0.0603,  0.0385, -0.0273],
#         [-0.0121,  0.0527,  0.0412],
#         [-0.0003, -0.0854,  0.0091]])
# tensor([[-0.1072, -0.0607, -0.0916],
#         [-0.1243,  0.1050, -0.0359],
#         [ 0.1094,  0.0073,  0.0910]])
# tensor([[ 0.0343,  0.0393,  0.0129],
#         [-0.0364, -0.0662, -0.0236],
#         [-0.0635,  0.0377,  0.0249]])
# tensor([[-0.0368,  0.0357,  0.0962],
#         [-0.0027, -0.0441,  0.1212],
#         [ 0.0023, -0.0796,  0.0161]])
# tensor([[-0.0077,  0.0697,  0.0127],
#         [-0.0361, -0.0424, -0.0740],
#         [ 0.0152,  0.0453, -0.0820]])
# tensor([[-0.0213,  0.0280,  0.0289],
#         [ 0.0301, -0.0802,  0.0281],
#         [ 0.0716,  0.0127,  0.0161]])
# tensor([[-0.0235,  0.0103, -0.0201],
#         [-0.0399,  0.0620, -0.0387],
#         [-0.0308,  0.0318, -0.0931]])

# %%
newModel

# %%
lm.freeze(tempModel,'vgg16')
